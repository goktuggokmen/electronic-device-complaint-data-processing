# %% [markdown]
# <a href="https://colab.research.google.com/github/goktuggokmen/electronic-device-complaint-data-processing/blob/main/Dizustu_Bilgisayar_Urun_Sikayet_Verilerinin_Analizi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**İZMİR DEMOKRASİ ÜNİVERSİTESİ**
# ##**ELEKTRİK-ELEKTRONİK MÜHENDİSLİĞİ BÖLÜMÜ**
# ##**2019-2020 YAZ DÖNEMİ STAJI**
# ##**ELEKTRONİK ÜRÜN ŞİKAYET VERİSİ TOPLAMA VE VERİLERİ İŞLEME (LAPTOPLAR) STAJ RAPORU**
#
# **AD :** Göktuğ
#
# **SOYAD :** GÖKMEN
#
# **ÖĞRENCİ NO :** 1806102007
#
# **SORUMLU AKADEMİSYEN :** Dr.Öğretim Üyesi Başak Esin KÖKTÜRK GÜZEL
#
# **STAJ SÜRESİ/ZAMANI :** 20 İŞ GÜNÜ / 17 AĞUSTOS 2020 - 11 EYLÜL 2020

# %% [markdown]
# # 1.HEDEF
# Çeşitli şikayet sitelerinde yayınlanmış bir elektronik ürün (örn. Laptop) kategorisindeki şikayetlerin toplanarak yapılandırılmış veri haline getirilmesi beklenmektedir. Örneğin bir laptop a ait, marka, model, işlemci tipi, ekran kartı modeli, şikayet metni ve özet şikayetin çıkarılması beklenmektedir. Proje sonunda toplanan veriler ile çeşitli analizler yapılacaktır.

# %% [markdown]
# # 2. KÜTÜPHANELERİN IMPORT EDİLMESİ VE VERİLERİN DOSYADAN OKUNMASI

# %% [markdown]
# > a.Kütüphanelerin import edilmesi

# %%
# Pandas kütüphanesinin yüklenmesi
import pandas as pd
# Matpotlib kütüphanesinin yüklenmesi
import matplotlib.pyplot as plt
#Seaborn kütüphanesinin yüklenmesi
import seaborn as sns

# %% [markdown]
# > b.Verilerin dosyadan okunması

# %%
data = pd.read_excel("/content/ELEKTRONİK ÜRÜN ŞİKAYET VERİSİ TOPLAMA (LAPTOPLAR).xlsx")

# %% [markdown]
# # 3.VERİ DOSYASININ İNCELENMESİ

# %%
#Verinin boyutları
data.shape
# Out:
# (1763, 51)

# %% [markdown]
# 1742 satır , 51 sütundan oluşan bir veri.

# %%
data.columns #Kolon isimleri
# Out:
# Index(['MARKA', 'MODEL', 'Cihaz Ağırlığı (kg)', 'Kalınlık (mm)',
#        'Sızdırma Korumalı (Su Sıçramalarına Karşı Dayanıklı)', 'Genişlik (mm)',
#        'Uzunluk (mm)', 'Döndür Ve Katla Tasarımına Sahiptir',
#        'Çözünürlük (px)', 'Ekran Boyutu (inç)',
#        'Yansıma Önleyici Kaplaması Vardır', 'Dokunmatik Ekran Vardır',
#        'Ekran Panel Tipi', 'Desteklenen Ekranlar', 'Ekran Kartı Modeli',
#        'Ekran Kartı Tipi', 'Ekran Kartı Bellek Tipi',
#        'Ekran Kartı Hafızası (GB)', 'İşlemci Modeli', 'İşlemci Nesli',
#        'İşlemci Hızı (GHz)', 'Ram (GB)', 'Ram Hızı (MHz)',
#        'İşlemci Çekirdek Sayısı', 'Dahili Hafıza (GB)',
#        'Harici Bellek Yuvası Vardır', 'CPU İş Parçacığı',
#        'HDD Depolama Kapasitesi (GB)', 'USB Type-C Mevcuttur', 'WiFi Özelliği',
#        'USB 3.0 Bağlantı Noktaları', 'HDMI Çıkışı Vardır', 'AirPlay'i Vardır',
#        'Thunderbolt Bağlantı Noktaları', 'USB 2.0 Bağlantı Noktaları',
#        'VGA Bağlantı Aparatı Vardır', 'Pil Ömrü (h)', 'Pil Gücü (mAh)',
#        'Pil Gücü (Wh)', 'Dahili Stereo Hoparlörü Vardır',
#        '3,5 mm Kulaklık Girişi Vardır', 'Parmak İzi Okuyucusu Mevcuttur',
#        'Mikrofon Sayısı', 'Sesli Komut Özelliği Vardır',
#        'Dahili Grafik Kartı Mevcuttur', 'GPU Bellek Hızı (MHz)',
#        'Boşta İken Güç Tüketimi (W)', 'Şikayet Başlığı', 'Şikayet Metni',
#        'Şikayet Kategorisi', 'Şikayet Linki'],
#       dtype='object')

# %%
#İlk 10 veri
data.head(10)
# Out:
#   MARKA  ...                                      Şikayet Linki
# 0  ACER  ...  https://www.hepsiburada.com/acer-aspire-3-a315...
# 1  ACER  ...  https://www.hepsiburada.com/acer-aspire-3-a315...
# 2  ACER  ...  https://www.vatanbilgisayar.com/acer-aspire-3-...
# 3  ACER  ...  https://www.cimri.com/dizustu-bilgisayar/en-uc...
# 4  ACER  ...  https://yorumbudur.com/yorumlar/129994/acer-a3...
# 5  ACER  ...  https://yorumbudur.com/yorumlar/129994/acer-a3...
# 6  ACER  ...  https://yorumbudur.com/yorumlar/129994/acer-a3...
# 7  ACER  ...  https://yorumbudur.com/yorumlar/129994/acer-a3...
# 8  ACER  ...  https://yorumbudur.com/yorumlar/129994/acer-a3...
# 9  ACER  ...  https://yorumbudur.com/yorumlar/129994/acer-a3...
#
# [10 rows x 51 columns]

# %%
#Son 10 veri
data.tail(10)
# Out:
#        MARKA  ...                                      Şikayet Linki
# 1753  LENOVO  ...  https://www.hepsiburada.com/lenovo-ideapad-l34...
# 1754  LENOVO  ...  https://www.hepsiburada.com/lenovo-ideapad-l34...
# 1755  LENOVO  ...  https://www.hepsiburada.com/lenovo-ideapad-l34...
# 1756  LENOVO  ...  https://www.hepsiburada.com/lenovo-ideapad-l34...
# 1757  LENOVO  ...  https://www.hepsiburada.com/lenovo-ideapad-l34...
# 1758  LENOVO  ...  https://www.hepsiburada.com/lenovo-ideapad-l34...
# 1759  LENOVO  ...  https://www.vatanbilgisayar.com/lenovo-ideapad...
# 1760  LENOVO  ...  https://www.vatanbilgisayar.com/lenovo-ideapad...
# 1761  LENOVO  ...  https://www.teknosa.com/lenovo-ideapad-l340-in...
# 1762  LENOVO  ...  https://www.teknosa.com/lenovo-ideapad-l340-in...
#
# [10 rows x 51 columns]

# %%
data.info() #Veriye dair genel bilgiler (Hangi kolonda ne kadar veri var ve bu verilerin türleri nelerdir ?)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1763 entries, 0 to 1762
# Data columns (total 51 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   MARKA                                                 1763 non-null   object
#  1   MODEL                                                 1763 non-null   object
#  2   Cihaz Ağırlığı (kg)                                   1763 non-null   float64
#  3   Kalınlık (mm)                                         1649 non-null   float64
#  4   Sızdırma Korumalı (Su Sıçramalarına Karşı Dayanıklı)  31 non-null     object
#  5   Genişlik (mm)                                         1649 non-null   float64
#  6   Uzunluk (mm)                                          1649 non-null   float64
#  7   Döndür Ve Katla Tasarımına Sahiptir                   1376 non-null   object
#  8   Çözünürlük (px)                                       1763 non-null   object
#  9   Ekran Boyutu (inç)                                    1763 non-null   float64
#  10  Yansıma Önleyici Kaplaması Vardır                     1310 non-null   object
#  11  Dokunmatik Ekran Vardır                               1749 non-null   object
#  12  Ekran Panel Tipi                                      1716 non-null   object
#  13  Desteklenen Ekranlar                                  1063 non-null   float64
#  14  Ekran Kartı Modeli                                    1763 non-null   object
#  15  Ekran Kartı Tipi                                      1747 non-null   object
#  16  Ekran Kartı Bellek Tipi                               1738 non-null   object
#  17  Ekran Kartı Hafızası (GB)                             1141 non-null   float64
#  18  İşlemci Modeli                                        1763 non-null   object
#  19  İşlemci Nesli                                         1504 non-null   object
#  20  İşlemci Hızı (GHz)                                    1763 non-null   float64
#  21  Ram (GB)                                              1763 non-null   int64
#  22  Ram Hızı (MHz)                                        1632 non-null   float64
#  23  İşlemci Çekirdek Sayısı                               1749 non-null   float64
#  24  Dahili Hafıza (GB)                                    1763 non-null   int64
#  25  Harici Bellek Yuvası Vardır                           1373 non-null   object
#  26  CPU İş Parçacığı                                      1716 non-null   float64
#  27  HDD Depolama Kapasitesi (GB)                          1365 non-null   float64
#  28  USB Type-C Mevcuttur                                  1687 non-null   object
#  29  WiFi Özelliği                                         1763 non-null   object
#  30  USB 3.0 Bağlantı Noktaları                            1740 non-null   float64
#  31  HDMI Çıkışı Vardır                                    1763 non-null   object
#  32  AirPlay'i Vardır                                      1753 non-null   object
#  33  Thunderbolt Bağlantı Noktaları                        1762 non-null   float64
#  34  USB 2.0 Bağlantı Noktaları                            1747 non-null   float64
#  35  VGA Bağlantı Aparatı Vardır                           1393 non-null   object
#  36  Pil Ömrü (h)                                          1313 non-null   float64
#  37  Pil Gücü (mAh)                                        497 non-null    float64
#  38  Pil Gücü (Wh)                                         1097 non-null   float64
#  39  Dahili Stereo Hoparlörü Vardır                        1343 non-null   object
#  40  3,5 mm Kulaklık Girişi Vardır                         1512 non-null   object
#  41  Parmak İzi Okuyucusu Mevcuttur                        1738 non-null   object
#  42  Mikrofon Sayısı                                       447 non-null    float64
#  43  Sesli Komut Özelliği Vardır                           182 non-null    object
#  44  Dahili Grafik Kartı Mevcuttur                         1740 non-null   object
#  45  GPU Bellek Hızı (MHz)                                 1699 non-null   float64
#  46  Boşta İken Güç Tüketimi (W)                           25 non-null     float64
#  47  Şikayet Başlığı                                       1234 non-null   object
#  48  Şikayet Metni                                         1763 non-null   object
#  49  Şikayet Kategorisi                                    1763 non-null   object
#  50  Şikayet Linki                                         1763 non-null   object
# dtypes: float64(21), int64(2), object(28)
# memory usage: 702.6+ KB

# %%
data.describe() #Sayısal veri içeren kolonlar'ın (float ve int) istatiksel analizi
# Out:
#        Cihaz Ağırlığı (kg)  ...  Boşta İken Güç Tüketimi (W)
# count          1763.000000  ...                    25.000000
# mean              2.040267  ...                    55.720000
# std               0.339965  ...                     5.488776
# min               1.200000  ...                    48.000000
# 25%               1.850000  ...                    52.000000
# 50%               2.100000  ...                    56.000000
# 75%               2.300000  ...                    56.000000
# max               3.910000  ...                    65.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# # 4.SÜTUNLARIN İNCELENMESİ VE GÖRSELLEŞTİRİLMESİ

# %% [markdown]
# **4.1) MARKA**

# %%
data['MARKA'].describe() # Sütuna ait genel bilgi
# Out:
# count     1763
# unique       8
# top       ASUS
# freq       720
# Name: MARKA, dtype: object

# %%
data["MARKA"].value_counts() # Hangi markadan ne kadar veri var ?
# Out:
# ASUS        720
# LENOVO      287
# HP          226
# ACER        191
# APPLE       108
# HOMETECH     98
# DELL         93
# CASPER       40
# Name: MARKA, dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["MARKA"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , startangle=90 , autopct='%1.1f%%') # Hangi markadan ne kadar veri olduğunun pasta grafiği ve yüzde olarak görselleştirilmesi
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e3b14d90>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞİ

# %%
data["MARKA"]=data["MARKA"].astype('category')
sns.countplot(x="MARKA", data=data)

# %% [markdown]
# **4.2) MODEL**

# %%
data['MODEL'].describe()
# Out:
# count                                                  1763
# unique                                                   87
# top       Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.3...
# freq                                                     87
# Name: MODEL, dtype: object

# %%
data["MODEL"].value_counts()
# Out:
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC             87
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD       68
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD         65
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB           52
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                 50
#                                                                                     ..
# Acer Aspire VN7-791G 17.3" Intel Core i7-4710HQ 2.5GHz / 16GB / 1TB\n                2
# Acer Nitro 5 15.6" Intel Core i5-9300H 2.4GHz / 8GB RAM / 256GB SSD                  2
# Acer Predator Helios 300 17.3" Intel Core i7-9750H 2.6GHz / 16GB RAM / 512GB SSD     2
# Apple MacBook Air (2020) 13.3" Intel Core i3 1.1GHz / 8GB RAM / 256 GB SSD           1
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 500 GB                  1
# Name: MODEL, Length: 87, dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["MODEL"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(20,8), edgecolor="#000000" , linewidth=3)
plt.xlabel("MODEL")
# Out:
# Text(0.5, 0, 'MODEL')

# %% [markdown]
# **4.3) CİHAZ AĞIRLIĞI**

# %%
data['Cihaz Ağırlığı (kg)'].describe()
# Out:
# count    1763.000000
# mean        2.040267
# std         0.339965
# min         1.200000
# 25%         1.850000
# 50%         2.100000
# 75%         2.300000
# max         3.910000
# Name: Cihaz Ağırlığı (kg), dtype: float64

# %%
data["Cihaz Ağırlığı (kg)"].value_counts()
# Out:
# 2.30    225
# 2.10    179
# 2.20    144
# 2.15    133
# 1.68    118
# 2.05    116
# 2.45    109
# 1.52     87
# 1.90     82
# 2.00     75
# 1.85     68
# 1.37     50
# 1.29     45
# 1.91     41
# 2.40     41
# 2.53     40
# 2.50     33
# 1.80     22
# 2.78     21
# 1.65     20
# 2.25     20
# 2.13     16
# 1.60     14
# 1.86     13
# 1.20     11
# 1.25     11
# 1.58      9
# 2.70      9
# 1.35      4
# 1.94      3
# 2.90      2
# 3.91      2
# Name: Cihaz Ağırlığı (kg), dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Cihaz Ağırlığı (kg)"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Cihaz Ağırlığı (kg)")
# Out:
# Text(0.5, 0, 'Cihaz Ağırlığı (kg)')

# %% [markdown]
# 4.4) KALINLIK

# %%
data['Kalınlık (mm)'].describe()
# Out:
# count    1649.000000
# mean       23.846665
# std         3.859317
# min        14.900000
# 25%        22.000000
# 50%        23.800000
# 75%        25.300000
# max        32.000000
# Name: Kalınlık (mm), dtype: float64

# %%
data["Kalınlık (mm)"].value_counts()
# Out:
# 23.00    287
# 24.00    225
# 22.00    210
# 27.00    147
# 25.00    133
# 20.00    128
# 32.00    109
# 17.00     55
# 30.00     51
# 23.80     41
# 14.90     40
# 29.90     40
# 25.30     21
# 25.50     20
# 29.00     16
# 22.90     15
# 18.00     14
# 15.60     11
# 19.00     11
# 23.10     11
# 15.00     10
# 17.95      9
# 26.00      9
# 26.80      9
# 21.00      7
# 25.90      5
# 17.20      4
# 19.90      3
# 28.00      3
# 25.40      2
# 24.60      2
# 16.10      1
# Name: Kalınlık (mm), dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Kalınlık (mm)"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Kalınlık (mm)")
# Out:
# Text(0.5, 0, 'Kalınlık (mm)')

# %% [markdown]
# **4.5) SIZDIRMA KORUMALI**

# %%
data['Sızdırma Korumalı (Su Sıçramalarına Karşı Dayanıklı)'].describe()
# Out:
# count        31
# unique        1
# top       Hayır
# freq         31
# Name: Sızdırma Korumalı (Su Sıçramalarına Karşı Dayanıklı), dtype: object

# %%
data["Sızdırma Korumalı (Su Sıçramalarına Karşı Dayanıklı)"].value_counts()
# Out:
# Hayır    31
# Name: Sızdırma Korumalı (Su Sıçramalarına Karşı Dayanıklı), dtype: int64

# %% [markdown]
# **4.6) GENİŞLİK**

# %%
data['Genişlik (mm)'].describe()
# Out:
# count    1649.000000
# mean      371.727835
# std        20.724763
# min       291.000000
# 25%       375.000000
# 50%       380.000000
# 75%       381.000000
# max       424.200000
# Name: Genişlik (mm), dtype: float64

# %%
data["Genişlik (mm)"].value_counts()
# Out:
# 380.0    527
# 382.0    214
# 378.0    137
# 381.0    127
# 375.0    116
# 362.0     68
# 365.0     66
# 304.1     52
# 361.0     52
# 325.0     44
# 390.0     43
# 382.8     40
# 359.0     22
# 413.0     21
# 339.0     20
# 383.0     17
# 363.4     16
# 360.2     15
# 323.0     14
# 291.0     11
# 304.0     10
# 314.0      9
# 325.1      4
# 424.2      2
# 403.9      2
# Name: Genişlik (mm), dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Genişlik (mm)"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Genişlik (mm)")
# Out:
# Text(0.5, 0, 'Genişlik (mm)')

# %% [markdown]
# **4.7) UZUNLUK**

# %%
data['Uzunluk (mm)'].describe()
# Out:
# count    1649.000000
# mean      251.734566
# std        12.559980
# min       211.000000
# 25%       251.000000
# 50%       253.000000
# 75%       258.000000
# max       292.100000
# Name: Uzunluk (mm), dtype: float64

# %%
data["Uzunluk (mm)"].value_counts()
# Out:
# 251.0    316
# 253.0    207
# 260.0    118
# 256.0    112
# 254.0    109
# 252.0    104
# 259.0     91
# 266.0     75
# 258.0     63
# 212.4     52
# 244.0     52
# 253.8     41
# 259.8     40
# 267.0     40
# 227.0     37
# 243.0     22
# 255.0     22
# 263.0     22
# 284.7     21
# 235.0     20
# 234.9     15
# 228.0     14
# 211.0     11
# 216.0     11
# 212.0     10
# 219.0      9
# 247.0      8
# 250.5      3
# 292.1      2
# 279.4      2
# Name: Uzunluk (mm), dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Uzunluk (mm)"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Uzunluk (mm)")
# Out:
# Text(0.5, 0, 'Uzunluk (mm)')

# %% [markdown]
# **4.8) DÖNDÜR VE KATLA TASARIMINA SAHİPTİR**

# %%
data['Döndür Ve Katla Tasarımına Sahiptir'].describe()
# Out:
# count      1376
# unique        2
# top       Hayır
# freq       1361
# Name: Döndür Ve Katla Tasarımına Sahiptir, dtype: object

# %%
data["Döndür Ve Katla Tasarımına Sahiptir"].value_counts()
# Out:
# Hayır    1361
# Evet       15
# Name: Döndür Ve Katla Tasarımına Sahiptir, dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Döndür Ve Katla Tasarımına Sahiptir"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , startangle=90 , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e4774790>],
#       dtype=object)

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Döndür Ve Katla Tasarımına Sahiptir"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Döndür Ve Katla Tasarımına Sahiptir")
# Out:
# Text(0.5, 0, 'Döndür Ve Katla Tasarımına Sahiptir')

# %% [markdown]
# **4.9) ÇÖZÜNÜRLÜK**

# %%
data['Çözünürlük (px)'].describe()
# Out:
# count           1763
# unique             5
# top       1366 x 768
# freq             988
# Name: Çözünürlük (px), dtype: object

# %%
data["Çözünürlük (px)"].value_counts()
# Out:
# 1366 x 768     988
# 1920 x 1080    627
# 2560 x 1600     71
# 3840 x 2160     40
# 1440 x 900      37
# Name: Çözünürlük (px), dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Çözünürlük (px)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,16) , shadow = True , startangle=90 , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e47bd790>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞİ

# %%
data["Çözünürlük (px)"]=data["Çözünürlük (px)"].astype('category')
sns.countplot(x= "Çözünürlük (px)", data=data)

# %% [markdown]
# **4.10) EKRAN BOYUTU**

# %%
data['Ekran Boyutu (inç)'].describe()
# Out:
# count    1763.000000
# mean       15.220647
# std         1.083791
# min        11.600000
# 25%        15.600000
# 50%        15.600000
# 75%        15.600000
# max        17.300000
# Name: Ekran Boyutu (inç), dtype: float64

# %%
data["Ekran Boyutu (inç)"].value_counts()
# Out:
# 15.6    1487
# 13.3     108
# 11.6      98
# 14.0      34
# 17.3      25
# 14.1      11
# Name: Ekran Boyutu (inç), dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Ekran Boyutu (inç)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,16) , shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0f0ae8710>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞİ

# %%
data["Ekran Boyutu (inç)"]=data["Ekran Boyutu (inç)"].astype('category')
sns.countplot(x= "Ekran Boyutu (inç)", data=data)

# %% [markdown]
# **4.11) YASIMA ÖNLEYİCİ KAPLAMASI VARDIR**

# %%
data['Yansıma Önleyici Kaplaması Vardır'].describe()
# Out:
# count     1310
# unique       2
# top       Evet
# freq       853
# Name: Yansıma Önleyici Kaplaması Vardır, dtype: object

# %%
data["Yansıma Önleyici Kaplaması Vardır"].value_counts()
# Out:
# Evet     853
# Hayır    457
# Name: Yansıma Önleyici Kaplaması Vardır, dtype: int64

# %%
data["Yansıma Önleyici Kaplaması Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e6881210>],
#       dtype=object)

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Yansıma Önleyici Kaplaması Vardır"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Yansıma Önleyici Kaplaması Vardır")
# Out:
# Text(0.5, 0, 'Yansıma Önleyici Kaplaması Vardır')

# %% [markdown]
# **4.12) DOKUNMATİK EKRAN VARDIR**

# %%
data['Dokunmatik Ekran Vardır'].describe()
# Out:
# count      1749
# unique        2
# top       Hayır
# freq       1734
# Name: Dokunmatik Ekran Vardır, dtype: object

# %%
data["Dokunmatik Ekran Vardır"].value_counts()
# Out:
# Hayır    1734
# Evet       15
# Name: Dokunmatik Ekran Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Dokunmatik Ekran Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e3e072d0>],
#       dtype=object)

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Dokunmatik Ekran Vardır"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Dokunmatik Ekran Vardır")
# Out:
# Text(0.5, 0, 'Dokunmatik Ekran Vardır')

# %% [markdown]
# **4.13) EKRAN PANEL TİPİ**

# %%
data['Ekran Panel Tipi'].describe()
# Out:
# count     1716
# unique       3
# top         TN
# freq      1197
# Name: Ekran Panel Tipi, dtype: object

# %%
data["Ekran Panel Tipi"].value_counts()
# Out:
# TN     1197
# IPS     293
# SVA     226
# Name: Ekran Panel Tipi, dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Ekran Panel Tipi"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e3cee690>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞİ

# %%
data["Ekran Panel Tipi"]=data["Ekran Panel Tipi"].astype('category')
sns.countplot(x= "Ekran Panel Tipi", data=data)

# %% [markdown]
# 4.14) DESTEKLENEN EKRANLAR

# %%
data['Desteklenen Ekranlar'].describe()
# Out:
# count    1063.000000
# mean        2.996237
# std         0.137180
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: Desteklenen Ekranlar, dtype: float64

# %%
data["Desteklenen Ekranlar"].value_counts()
# Out:
# 3.0    1059
# 4.0       2
# 0.0       2
# Name: Desteklenen Ekranlar, dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Desteklenen Ekranlar"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , startangle=90 , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e4834bd0>],
#       dtype=object)

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Desteklenen Ekranlar"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Desteklenen Ekranlar")
# Out:
# Text(0.5, 0, 'Desteklenen Ekranlar')

# %% [markdown]
# 4.15) EKRAN KARTI MODELİ

# %%
data['Ekran Kartı Modeli'].describe()
# Out:
# count               1763
# unique                50
# top       AMD Radeon 530
# freq                 182
# Name: Ekran Kartı Modeli, dtype: object

# %%
data['Ekran Kartı Modeli'].value_counts()
# Out:
# AMD Radeon 530                  182
# Nvidia GeForce GTX950M          109
# Intel HD Graphics 400            99
# Intel HD Graphics                98
# Nvidia GeForce GT940MX           86
# Intel HD Graphics 5500           85
# AMD Radeon 520                   82
# Nvidia GeForce GT940M            73
# Intel UHD Graphics 600           69
# Nvidia GeForce 930MX             68
# AMD Radeon Vega 10               68
# Nvidia GeForce GT930MX           65
# AMD Radeon R5 M420               52
# Intel HD Graphics 500            46
# NVIDIA GeForce GTX 1050          40
# Nvidia GeForce GTX960M           40
# Intel HD Graphics 6000           37
# NVIDIA GeForce MX100             35
# AMD Radeon R7 M445               34
# AMD Radeon R2 Graphics           33
# Nvidia GeForce MX110             28
# Intel Iris Pro Graphics          27
# Nvidia GeForce GTX1050 Ti        25
# Nvidia GeForce GTX1650           24
# Nvidia GeForce MX150             22
# AMD Radeon R4                    22
# AMD Radeon R5 M430               20
# \tNvidia GeForce GT940MX         20
# Nvidia GeForce GTX1050           17
# Nvidia GeForce MX130             16
# NVIDIA GeForce 940MX             16
# AMD Radeon 530X                  14
# Intel UHD Graphics 617           11
# AMD Radeon Vega 3                11
# Intel Iris Plus 645              10
# Intel Iris Graphics 6100          9
# Intel UHD Graphics 620            9
# AMD Radeon 540X                   8
# Intel Iris Plus 640               7
# AMD Radeon 500                    7
# Intel HD Graphics 620             7
# Intel Iris Plus Graphics 655      6
# Nvidia GeForce GT920MX            5
# Nvidia GeForce 940M               5
# Nvidia GeForce MX250              5
# Intel HD Graphics 520             4
# Nvidia Geforce GTX1660 Ti         2
# Nvidia GeForce GTX860M            2
# \tNvidia GeForce GTX1050          2
# Intel Iris Plus Graphics          1
# Name: Ekran Kartı Modeli, dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Ekran Kartı Modeli"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(12,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Ekran Kartı Modeli")
# Out:
# Text(0.5, 0, 'Ekran Kartı Modeli')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# **4.16) EKRAN KARTI TİPİ**

# %%
data['Ekran Kartı Tipi'].describe()
# Out:
# count                   1747
# unique                     3
# top       Harici Ekran Kartı
# freq                     991
# Name: Ekran Kartı Tipi, dtype: object

# %%
data['Ekran Kartı Tipi'].value_counts()
# Out:
# Harici Ekran Kartı                  991
# Dahili Ekran Kartı                  666
# Yüksek Seviye Harici Ekran Kartı     90
# Name: Ekran Kartı Tipi, dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Ekran Kartı Tipi"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e38eb910>],
#       dtype=object)

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["Ekran Kartı Tipi"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Ekran Kartı Tipi")
# Out:
# Text(0.5, 0, 'Ekran Kartı Tipi')

# %% [markdown]
# 4.17) EKRAN KARTI BELLEK TİPi

# %%
data['Ekran Kartı Bellek Tipi'].describe()
# Out:
# count      1738
# unique        5
# top       GDDR5
# freq        674
# Name: Ekran Kartı Bellek Tipi, dtype: object

# %%
data['Ekran Kartı Bellek Tipi'].value_counts()
# Out:
# GDDR5      674
# Onboard    624
# DDR3       334
# GDDR3       86
# GDDR4       20
# Name: Ekran Kartı Bellek Tipi, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Ekran Kartı Bellek Tipi"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e382f050>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞİ

# %%
data["Ekran Kartı Bellek Tipi"]=data["Ekran Kartı Bellek Tipi"].astype('category')
sns.countplot(x= "Ekran Kartı Bellek Tipi", data=data)

# %% [markdown]
# **4.18) Ekran Kartı Hafızası**

# %%
data["Ekran Kartı Hafızası (GB)"].describe()
# Out:
# count    1141.000000
# mean        2.419807
# std         0.836614
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         2.000000
# max         6.000000
# Name: Ekran Kartı Hafızası (GB), dtype: float64

# %%
data["Ekran Kartı Hafızası (GB)"].value_counts()
# Out:
# 2.0    889
# 4.0    239
# 1.0      9
# 6.0      2
# 3.0      2
# Name: Ekran Kartı Hafızası (GB), dtype: int64

# %% [markdown]
# PASTA GRAFİĞİ

# %%
data["Ekran Kartı Hafızası (GB)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,16) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e376ca50>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞİ

# %%
data["Ekran Kartı Hafızası (GB)"]=data["Ekran Kartı Hafızası (GB)"].astype('category')
sns.countplot(x= "Ekran Kartı Hafızası (GB)", data=data)

# %% [markdown]
# **4.19) İŞLEMCİ MODELİ**

# %%
data["İşlemci Modeli"].describe()
# Out:
# count                    1763
# unique                     40
# top       Intel Core i5-8250U
# freq                      255
# Name: İşlemci Modeli, dtype: object

# %%
data["İşlemci Modeli"].value_counts()
# Out:
# Intel Core i5-8250U      255
# Intel Core i5-7200U      221
# Intel Core i7-6700HQ     149
# Intel Celeron-N3060       99
# Intel Atom Z3735F         98
# AMD A9-9420               93
# Intel Core i3-5005U       85
# Intel Celeron-N4000       69
# AMD Ryzen 7-3700U         68
# Intel Core i7-7700HQ      66
# Intel Core i5-6200U       57
# Intel Celeron-N3350       46
# Intel Core i7-8550U       45
# Intel Core i5-8265U       38
# Intel Core i5-7360U       34
# AMD E1-7010               33
# Intel Core i5-5350U       33
# AMD A12-9720P             32
# Intel Core i3-6006U       24
# Intel Core i7-9750H       23
# AMD A6-9220               22
# Intel Core i7-7500U       20
# Intel Core i5-8300H       16
# Intel Core i5-6200U       16
# AMD Ryzen 3-2200          14
# Intel Core i3-7020U       13
# AMD Ryzen 3-3200U         11
# Intel Core i5-8210Y       11
# Intel Core i5-8257U       10
# Intel Core i3-8145U        9
# Intel Core i5-5257U        9
# AMD Ryzen 5-3500U          8
# Intel Core i3 6006U        8
# Intel Core i5-8259U        6
# Intel Core i5-9300H        5
# Intel Core i5-5200U        5
# Intel Core i5-10210U       5
# Intel Core i5-5250U        4
# Intel Core i7-4710HQ       2
# Intel Core i3-1000NG4      1
# Name: İşlemci Modeli, dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["İşlemci Modeli"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(12,8), edgecolor="#000000" , linewidth=3)
plt.xlabel("İşlemci Modeli")
# Out:
# Text(0.5, 0, 'İşlemci Modeli')

# %% [markdown]
# **4.20) İŞLEMCİ NESLİ**

# %%
data["İşlemci Nesli"].describe()
# Out:
# count        1504
# unique         11
# top       8.Nesil
# freq          390
# Name: İşlemci Nesli, dtype: object

# %%
data["İşlemci Nesli"].value_counts()
# Out:
# 8.Nesil          390
# 7.Nesil          388
# 6.Nesil          254
# Intel Celeron    180
# 5.Nesil          136
# Intel Atom        98
# 9.Nesil           28
# Ryzen             14
# 3.Nesil            8
# 10.Nesil           6
# 4.Nesil            2
# Name: İşlemci Nesli, dtype: int64

# %% [markdown]
# SÜTUN GRAFİĞİ

# %%
data["İşlemci Nesli"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("İşlemci Nesli")
# Out:
# Text(0.5, 0, 'İşlemci Nesli')

# %% [markdown]
# **4.21) İŞLEMCİ HIZI**

# %%
data["İşlemci Hızı (GHz)"].describe()
# Out:
# count    1763.000000
# mean        2.093500
# std         0.532169
# min         1.100000
# 25%         1.600000
# 50%         2.300000
# 75%         2.500000
# max         3.800000
# Name: İşlemci Hızı (GHz), dtype: float64

# %%
data["İşlemci Hızı (GHz)"].value_counts()
# Out:
# 1.60    412
# 2.50    280
# 2.30    194
# 2.60    183
# 2.00    133
# 1.33     98
# 2.90     93
# 1.10     79
# 1.80     78
# 2.70     61
# 2.80     57
# 1.50     33
# 2.20     21
# 2.10     17
# 1.44     10
# 3.80      9
# 2.40      5
# Name: İşlemci Hızı (GHz), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["İşlemci Hızı (GHz)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,16) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e3498950>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["İşlemci Hızı (GHz)"]=data["İşlemci Hızı (GHz)"].astype('category')
sns.countplot(x= "İşlemci Hızı (GHz)", data=data)

# %% [markdown]
# **4.22) RAM**

# %%
data["Ram (GB)"].describe()
# Out:
# count    1763.000000
# mean        6.713556
# std         3.846247
# min         2.000000
# 25%         4.000000
# 50%         4.000000
# 75%         8.000000
# max        16.000000
# Name: Ram (GB), dtype: float64

# %%
data["Ram (GB)"].value_counts()
# Out:
# 4     754
# 8     636
# 16    169
# 2     142
# 12     62
# Name: Ram (GB), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Ram (GB)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e4210d10>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Ram (GB)"]=data["Ram (GB)"].astype('category')
sns.countplot(x= "Ram (GB)", data=data)

# %% [markdown]
# **4.22) RAM HIZI**

# %%
data["Ram Hızı (MHz)"].describe()
# Out:
# count    1632.000000
# mean     2032.661152
# std       312.844472
# min      1066.000000
# 25%      1600.000000
# 50%      2133.000000
# 75%      2133.000000
# max      3733.000000
# Name: Ram Hızı (MHz), dtype: float64

# %%
data["Ram Hızı (MHz)"].value_counts()
# Out:
# 2133.0    781
# 1600.0    439
# 2400.0    351
# 1866.0     31
# 1066.0     11
# 1333.0     11
# 2666.0      7
# 3733.0      1
# Name: Ram Hızı (MHz), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Ram Hızı (MHz)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,16) , startangle = 180 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e3276fd0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Ram Hızı (MHz)"]=data["Ram Hızı (MHz)"].astype('category')
sns.countplot(x= "Ram Hızı (MHz)", data=data)

# %% [markdown]
# **4.23) İŞLEMCİ ÇEKİRDEK SAYISI**

# %%
data["İşlemci Çekirdek Sayısı"].describe()
# Out:
# count    1749.000000
# mean        2.970840
# std         1.051182
# min         2.000000
# 25%         2.000000
# 50%         2.000000
# 75%         4.000000
# max         6.000000
# Name: İşlemci Çekirdek Sayısı, dtype: float64

# %%
data["İşlemci Çekirdek Sayısı"].value_counts()
# Out:
# 2.0    923
# 4.0    803
# 6.0     23
# Name: İşlemci Çekirdek Sayısı, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["İşlemci Çekirdek Sayısı"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e30f2350>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["İşlemci Çekirdek Sayısı"]=data["İşlemci Çekirdek Sayısı"].astype('category')
sns.countplot(x= "İşlemci Çekirdek Sayısı", data=data)

# %% [markdown]
# **4.24) DAHİLİ HAFIZA**

# %%
data["Dahili Hafıza (GB)"].describe()
# Out:
# count    1763.000000
# mean      746.938174
# std       376.967381
# min        32.000000
# 25%       512.000000
# 50%      1000.000000
# 75%      1000.000000
# max      1256.000000
# Name: Dahili Hafıza (GB), dtype: float64

# %%
data["Dahili Hafıza (GB)"].value_counts()
# Out:
# 1000    874
# 512     289
# 128     147
# 1128    119
# 32      109
# 256      77
# 1256     70
# 500      59
# 64       19
# Name: Dahili Hafıza (GB), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Dahili Hafıza (GB)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e30af390>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Dahili Hafıza (GB)"]=data["Dahili Hafıza (GB)"].astype('category')
sns.countplot(x= "Dahili Hafıza (GB)", data=data)

# %% [markdown]
# **4.25) HARİCİ BELLEK YUVASI VARDIR**

# %%
data["Harici Bellek Yuvası Vardır"].describe()
# Out:
# count     1373
# unique       2
# top       Evet
# freq      1224
# Name: Harici Bellek Yuvası Vardır, dtype: object

# %%
data["Harici Bellek Yuvası Vardır"].value_counts()
# Out:
# Evet     1224
# Hayır     149
# Name: Harici Bellek Yuvası Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Harici Bellek Yuvası Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2f475d0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Harici Bellek Yuvası Vardır"]=data["Harici Bellek Yuvası Vardır"].astype('category')
sns.countplot(x= "Harici Bellek Yuvası Vardır", data=data)

# %% [markdown]
# **4.26) CPU İŞ PARÇACIĞI**

# %%
data["CPU İş Parçacığı"].describe()
# Out:
# count    1716.000000
# mean        5.227273
# std         2.510777
# min         2.000000
# 25%         4.000000
# 50%         4.000000
# 75%         8.000000
# max        12.000000
# Name: CPU İş Parçacığı, dtype: float64

# %%
data["CPU İş Parçacığı"].value_counts()
# Out:
# 4.0     683
# 8.0     657
# 2.0     353
# 12.0     23
# Name: CPU İş Parçacığı, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["CPU İş Parçacığı"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2e76390>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["CPU İş Parçacığı"]=data["CPU İş Parçacığı"].astype('category')
sns.countplot(x= "CPU İş Parçacığı", data=data)

# %% [markdown]
# **4.27) HDD DEPOLAMA KAPASİTESİ**

# %%
data["HDD Depolama Kapasitesi (GB)"].describe()
# Out:
# count    1365.000000
# mean      889.175092
# std       212.514873
# min       256.000000
# 25%      1000.000000
# 50%      1000.000000
# 75%      1000.000000
# max      1000.000000
# Name: HDD Depolama Kapasitesi (GB), dtype: float64

# %%
data["HDD Depolama Kapasitesi (GB)"].value_counts()
# Out:
# 1000.0    1068
# 512.0      216
# 500.0       59
# 256.0       22
# Name: HDD Depolama Kapasitesi (GB), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["HDD Depolama Kapasitesi (GB)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2db78d0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["HDD Depolama Kapasitesi (GB)"]=data["HDD Depolama Kapasitesi (GB)"].astype('category')
sns.countplot(x= "HDD Depolama Kapasitesi (GB)", data=data)

# %% [markdown]
# **4.28) USB TYPE-C MEVCUTTUR**

# %%
data["USB Type-C Mevcuttur"].describe()
# Out:
# count     1687
# unique       2
# top       Evet
# freq       903
# Name: USB Type-C Mevcuttur, dtype: object

# %%
data["USB Type-C Mevcuttur"].value_counts()
# Out:
# Evet     903
# Hayır    784
# Name: USB Type-C Mevcuttur, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["USB Type-C Mevcuttur"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2d09910>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["USB Type-C Mevcuttur"]=data["USB Type-C Mevcuttur"].astype('category')
sns.countplot(x= "USB Type-C Mevcuttur", data=data)

# %% [markdown]
# **4.28) WİFİ ÖZELLİĞİ**

# %%
data["WiFi Özelliği"].describe()
# Out:
# count     1763
# unique       1
# top       Evet
# freq      1763
# Name: WiFi Özelliği, dtype: object

# %%
data["WiFi Özelliği"].value_counts()
# Out:
# Evet    1763
# Name: WiFi Özelliği, dtype: int64

# %% [markdown]
# **4.29) USB 3.0 BAĞLANTI NOKTALARI**

# %%
data["USB 3.0 Bağlantı Noktaları"].describe()
# Out:
# count    1740.000000
# mean        1.605747
# std         0.698945
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: USB 3.0 Bağlantı Noktaları, dtype: float64

# %%
data["USB 3.0 Bağlantı Noktaları"].value_counts()
# Out:
# 2.0    1085
# 1.0     442
# 0.0     153
# 3.0      58
# 4.0       2
# Name: USB 3.0 Bağlantı Noktaları, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["USB 3.0 Bağlantı Noktaları"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2c588d0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["USB 3.0 Bağlantı Noktaları"]=data["USB 3.0 Bağlantı Noktaları"].astype('category')
sns.countplot(x= "USB 3.0 Bağlantı Noktaları", data=data)

# %% [markdown]
# **4.30) HDMI ÇIKIŞI VARDIR**

# %%
data["HDMI Çıkışı Vardır"].describe()
# Out:
# count     1763
# unique       2
# top       Evet
# freq      1664
# Name: HDMI Çıkışı Vardır, dtype: object

# %%
data["HDMI Çıkışı Vardır"].value_counts()
# Out:
# Evet     1664
# Hayır      99
# Name: HDMI Çıkışı Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["HDMI Çıkışı Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2b7a790>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["HDMI Çıkışı Vardır"]=data["HDMI Çıkışı Vardır"].astype('category')
sns.countplot(x= "HDMI Çıkışı Vardır", data=data)

# %% [markdown]
# **4.31) AİRPLAY'İ VARDIR**

# %%
data["AirPlay'i Vardır"].describe()
# Out:
# count      1753
# unique        2
# top       Hayır
# freq       1700
# Name: AirPlay'i Vardır, dtype: object

# %%
data["AirPlay'i Vardır"].value_counts()
# Out:
# Hayır    1700
# Evet       53
# Name: AirPlay'i Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["AirPlay'i Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2c54190>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["AirPlay'i Vardır"]=data["AirPlay'i Vardır"].astype('category')
sns.countplot(x= "AirPlay'i Vardır", data=data)

# %% [markdown]
# **4.32) THUNDERBOLT BAĞLANTI NOKTALARI**

# %%
data["Thunderbolt Bağlantı Noktaları"].describe()
# Out:
# count    1762.000000
# mean        0.137911
# std         0.621171
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         4.000000
# Name: Thunderbolt Bağlantı Noktaları, dtype: float64

# %%
data["Thunderbolt Bağlantı Noktaları"].value_counts()
# Out:
# 0.0    1655
# 2.0      37
# 1.0      37
# 4.0      33
# Name: Thunderbolt Bağlantı Noktaları, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Thunderbolt Bağlantı Noktaları"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e29f7fd0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Thunderbolt Bağlantı Noktaları"]=data["Thunderbolt Bağlantı Noktaları"].astype('category')
sns.countplot(x= "Thunderbolt Bağlantı Noktaları", data=data)

# %% [markdown]
# **4.33) USB 2.0 BAĞLANTI NOKTALARI**

# %%
data["USB 2.0 Bağlantı Noktaları"].describe()
# Out:
# count    1747.000000
# mean        1.018317
# std         0.663832
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: USB 2.0 Bağlantı Noktaları, dtype: float64

# %%
data["USB 2.0 Bağlantı Noktaları"].value_counts()
# Out:
# 1.0    977
# 2.0    401
# 0.0    369
# Name: USB 2.0 Bağlantı Noktaları, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["USB 2.0 Bağlantı Noktaları"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e29616d0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["USB 2.0 Bağlantı Noktaları"]=data["USB 2.0 Bağlantı Noktaları"].astype('category')
sns.countplot(x= "USB 2.0 Bağlantı Noktaları", data=data)

# %% [markdown]
# **4.34) VGA BAĞLANTI APARATI VARDIR**

# %%
data["VGA Bağlantı Aparatı Vardır"].describe()
# Out:
# count      1393
# unique        2
# top       Hayır
# freq        705
# Name: VGA Bağlantı Aparatı Vardır, dtype: object

# %%
data["VGA Bağlantı Aparatı Vardır"].value_counts()
# Out:
# Hayır    705
# Evet     688
# Name: VGA Bağlantı Aparatı Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["VGA Bağlantı Aparatı Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e289bfd0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["VGA Bağlantı Aparatı Vardır"]=data["VGA Bağlantı Aparatı Vardır"].astype('category')
sns.countplot(x= "VGA Bağlantı Aparatı Vardır", data=data)

# %% [markdown]
# **4.35) PİL ÖMRÜ**

# %%
data["Pil Ömrü (h)"].describe()
# Out:
# count    1313.000000
# mean        6.582254
# std         3.232966
# min         1.000000
# 25%         4.000000
# 50%         6.000000
# 75%        10.000000
# max        14.000000
# Name: Pil Ömrü (h), dtype: float64

# %%
data["Pil Ömrü (h)"].value_counts()
# Out:
# 4.0     321
# 12.0    236
# 6.0     226
# 5.0     156
# 10.0     83
# 3.0      69
# 1.0      45
# 8.0      40
# 4.5      32
# 7.5      22
# 9.0      21
# 6.5      21
# 7.0      13
# 8.5       9
# 5.5       9
# 14.0      9
# 11.0      1
# Name: Pil Ömrü (h), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Pil Ömrü (h)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,12) , startangle = 180 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2884390>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Pil Ömrü (h)"]=data["Pil Ömrü (h)"].astype('category')
sns.countplot(x= "Pil Ömrü (h)", data=data)

# %% [markdown]
# **4.36) PİL GÜCÜ (mAh)**

# %%
data["Pil Gücü (mAh)"].describe()
# Out:
# count      497.000000
# mean      4624.237425
# std       1652.902908
# min       2520.000000
# 25%       3220.000000
# 50%       4400.000000
# 75%       5001.000000
# max      10000.000000
# Name: Pil Gücü (mAh), dtype: float64

# %%
data["Pil Gücü (mAh)"].value_counts()
# Out:
# 3220.0     88
# 7000.0     87
# 4840.0     54
# 2800.0     45
# 5001.0     45
# 3200.0     40
# 4400.0     40
# 3570.0     21
# 4870.0     14
# 10000.0    11
# 3770.0     11
# 4810.0     10
# 6559.0      9
# 3320.0      9
# 2520.0      5
# 7150.0      4
# 3720.0      2
# 4605.0      2
# Name: Pil Gücü (mAh), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Pil Gücü (mAh)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,12) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2658f90>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Pil Gücü (mAh)"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(8,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("Pil Gücü (mAh)")
# Out:
# Text(0.5, 0, 'Pil Gücü (mAh)')

# %% [markdown]
# **4.37) PİL GÜCÜ (Wh)**

# %%
data["Pil Gücü (Wh)"].describe()
# Out:
# count    1097.000000
# mean       37.524157
# std         8.470624
# min        30.000000
# 25%        31.000000
# 50%        33.000000
# 75%        42.000000
# max        70.000000
# Name: Pil Gücü (Wh), dtype: float64

# %%
data["Pil Gücü (Wh)"].value_counts()
# Out:
# 30.0    266
# 33.0    147
# 31.0    135
# 44.0    109
# 38.0     90
# 42.0     86
# 48.0     77
# 41.0     73
# 40.0     36
# 70.0     33
# 45.0     21
# 32.0     15
# 58.0      6
# 36.0      3
# Name: Pil Gücü (Wh), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Pil Gücü (Wh)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,12) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e24ecf90>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Pil Gücü (Wh)"]=data["Pil Gücü (Wh)"].astype('category')
sns.countplot(x= "Pil Gücü (Wh)", data=data)

# %% [markdown]
# **4.38) DAHİLİ STEREO HOPARLÖR VARDIR**

# %%
data["Dahili Stereo Hoparlörü Vardır"].describe()
# Out:
# count     1343
# unique       1
# top       Evet
# freq      1343
# Name: Dahili Stereo Hoparlörü Vardır, dtype: object

# %%
data["Dahili Stereo Hoparlörü Vardır"].value_counts()
# Out:
# Evet    1343
# Name: Dahili Stereo Hoparlörü Vardır, dtype: int64

# %% [markdown]
# **4.39) 3.5 MM KULAKLIK GİRİŞİ VARDIR**

# %%
data["3,5 mm Kulaklık Girişi Vardır"].describe()
# Out:
# count     1512
# unique       2
# top       Evet
# freq      1476
# Name: 3,5 mm Kulaklık Girişi Vardır, dtype: object

# %%
data["3,5 mm Kulaklık Girişi Vardır"].value_counts()
# Out:
# Evet     1476
# Hayır      36
# Name: 3,5 mm Kulaklık Girişi Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["3,5 mm Kulaklık Girişi Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e23401d0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["3,5 mm Kulaklık Girişi Vardır"]=data["3,5 mm Kulaklık Girişi Vardır"].astype('category')
sns.countplot(x= "3,5 mm Kulaklık Girişi Vardır", data=data)

# %% [markdown]
# **4.40) PARMAK İZİ OKUYUCUSU MEVCUTTUR**

# %%
data["Parmak İzi Okuyucusu Mevcuttur"].describe()
# Out:
# count      1738
# unique        2
# top       Hayır
# freq       1414
# Name: Parmak İzi Okuyucusu Mevcuttur, dtype: object

# %%
data["Parmak İzi Okuyucusu Mevcuttur"].value_counts()
# Out:
# Hayır    1414
# Evet      324
# Name: Parmak İzi Okuyucusu Mevcuttur, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Parmak İzi Okuyucusu Mevcuttur"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2272b10>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Parmak İzi Okuyucusu Mevcuttur"]=data["Parmak İzi Okuyucusu Mevcuttur"].astype('category')
sns.countplot(x= "Parmak İzi Okuyucusu Mevcuttur", data=data)

# %% [markdown]
# **4.41) MİKROFON SAYISI**

# %%
data["Mikrofon Sayısı"].describe()
# Out:
# count    447.000000
# mean       1.230425
# std        0.550715
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: Mikrofon Sayısı, dtype: float64

# %%
data["Mikrofon Sayısı"].value_counts()
# Out:
# 1.0    372
# 2.0     47
# 3.0     28
# Name: Mikrofon Sayısı, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Mikrofon Sayısı"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e23a3fd0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Mikrofon Sayısı"]=data["Mikrofon Sayısı"].astype('category')
sns.countplot(x= "Mikrofon Sayısı", data=data)

# %% [markdown]
# **4.42) SESLİ KOMUT ÖZELLİĞİ VARDIR**

# %%
data["Sesli Komut Özelliği Vardır"].describe()
# Out:
# count       182
# unique        2
# top       Hayır
# freq        156
# Name: Sesli Komut Özelliği Vardır, dtype: object

# %%
data["Sesli Komut Özelliği Vardır"].value_counts()
# Out:
# Hayır    156
# Evet      26
# Name: Sesli Komut Özelliği Vardır, dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Sesli Komut Özelliği Vardır"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e2168b90>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Sesli Komut Özelliği Vardır"]=data["Sesli Komut Özelliği Vardır"].astype('category')
sns.countplot(x= "Sesli Komut Özelliği Vardır", data=data)

# %% [markdown]
# **4.43) DAHİLİ GRAFİK KARTI MEVCUTTUR**

# %%
data["Dahili Grafik Kartı Mevcuttur"].describe()
# Out:
# count     1740
# unique       1
# top       Evet
# freq      1740
# Name: Dahili Grafik Kartı Mevcuttur, dtype: object

# %%
data["Dahili Grafik Kartı Mevcuttur"].value_counts()
# Out:
# Evet    1740
# Name: Dahili Grafik Kartı Mevcuttur, dtype: int64

# %% [markdown]
# **4.44) GPU BELLEK HIZI**

# %%
data["GPU Bellek Hızı (MHz)"].describe()
# Out:
# count    1699.000000
# mean      798.966451
# std       390.352152
# min       200.000000
# 25%       320.000000
# 50%       952.000000
# 75%      1030.000000
# max      2000.000000
# Name: GPU Bellek Hızı (MHz), dtype: float64

# %%
data["GPU Bellek Hızı (MHz)"].value_counts()
# Out:
# 300.0     213
# 1024.0    148
# 952.0     131
# 200.0     112
# 914.0     109
# 780.0     106
# 1072.0    103
# 311.0      98
# 320.0      90
# 1030.0     82
# 967.0      75
# 1400.0     68
# 965.0      63
# 1354.0     57
# 1468.0     46
# 1096.0     40
# 400.0      33
# 655.0      22
# 1485.0     21
# 1200.0     19
# 1000.0     14
# 730.0      14
# 600.0       9
# 800.0       7
# 937.0       5
# 1100.0      5
# 2000.0      3
# 1752.0      2
# 1500.0      2
# 925.0       2
# Name: GPU Bellek Hızı (MHz), dtype: int64

# %% [markdown]
# BAR GRAFİĞi

# %%
data["GPU Bellek Hızı (MHz)"].value_counts().plot(kind='bar', color="#ff0000" , figsize=(12,4), edgecolor="#000000" , linewidth=3)
plt.xlabel("GPU Bellek Hızı (MHz)")
# Out:
# Text(0.5, 0, 'GPU Bellek Hızı (MHz)')

# %% [markdown]
# **4.45) BOŞTA İKEN GÜÇ TÜKETİMİ**

# %%
data["Boşta İken Güç Tüketimi (W)"].describe()
# Out:
# count    25.000000
# mean     55.720000
# std       5.488776
# min      48.000000
# 25%      52.000000
# 50%      56.000000
# 75%      56.000000
# max      65.000000
# Name: Boşta İken Güç Tüketimi (W), dtype: float64

# %%
data["Boşta İken Güç Tüketimi (W)"].value_counts()
# Out:
# 56.0    9
# 65.0    5
# 54.0    4
# 48.0    4
# 52.0    3
# Name: Boşta İken Güç Tüketimi (W), dtype: int64

# %% [markdown]
# PASTA GRAFİĞi

# %%
data["Boşta İken Güç Tüketimi (W)"].value_counts().plot(kind='pie', subplots=True, figsize=(16,8) , startangle = 0 ,shadow = True , autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0e1f78dd0>],
#       dtype=object)

# %% [markdown]
# BAR GRAFİĞi

# %%
data["Boşta İken Güç Tüketimi (W)"]=data["Boşta İken Güç Tüketimi (W)"].astype('category')
sns.countplot(x= "Boşta İken Güç Tüketimi (W)", data=data)

# %% [markdown]
# # 5.ŞİKAYET KATEGORİLERİNİN İNCELENMESİ

# %% [markdown]
# # **5.1) Arızalı Ürün**

# %%
arizali_urun = data[data['Şikayet Kategorisi'].str.contains('Arızalı ürün')]

# %%
arizali_urun[['MARKA','MODEL','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 299 to 1722
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MARKA               62 non-null     category
#  1   MODEL               62 non-null     object
#  2   Şikayet Kategorisi  62 non-null     object
# dtypes: category(1), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# "Arızalı Ürün" şikayet kategorisine ait 62 veri var.

# %%
arizali_urun[['MARKA','MODEL','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count     62  ...                 62
# unique     5  ...                 21
# top     ASUS  ...       Arızalı ürün
# freq      48  ...                 42
#
# [4 rows x 3 columns]

# %% [markdown]
# > *   Arızalı ürün şikayetinin markalara göre kıyaslaması

# %%
arizali_urun["MARKA"].value_counts()
# Out:
# ASUS        48
# HP           6
# HOMETECH     6
# LENOVO       1
# CASPER       1
# DELL         0
# APPLE        0
# ACER         0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Arızalı ürün" şikayetini en çok alan marka 48 şikayetle "ASUS"

# %% [markdown]
# > *   Arızalı ürün şikayetinin modele göre kıyaslaması

# %%
arizali_urun["MODEL"].value_counts()
# Out:
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB    12
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                             7
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                       5
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                    3
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                         2
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                   2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                     2
# Asus FX553VD-DM160 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD          2
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                          2
# Asus X540UB-GO072 15.6" Intel Core i5-7200U 2.2 GHz / 4 GB / 1 TB                             2
# Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD                   2
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                        2
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                             2
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                      1
# Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB                         1
# Asus K555UQ-DM028DC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 1000 GB HDD                    1
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                    1
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD             1
# Asus X541SA-XX038D 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                      1
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                     1
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                           1
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD       1
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 500 GB                           1
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                         1
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 12 GB / 1 TB                           1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 256 GB SSD           1
# Asus X507MA-BR001T 15.6" Intel Celeron-N4000 2.5 GHz / 4 GB / 512 GB                          1
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                     1
# Hometech HT BOOK 14 14.1"  Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                     1
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD           1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Arızalı ürün" şikayetini en çok alan model 12 şikayetle "Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB" ve onu takip eden 7 şikayetle "Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB"

# %%
corr = arizali_urun.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.2) Batarya Performansı**

# %%
batarya_performansi = data[data['Şikayet Kategorisi'].str.contains('Batarya performansı')]

# %%
batarya_performansi[['MARKA','MODEL','Pil Ömrü (h)','Pil Gücü (mAh)','Pil Gücü (Wh)','Boşta İken Güç Tüketimi (W)','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 10 to 1762
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MARKA                        134 non-null    category
#  1   MODEL                        134 non-null    object
#  2   Pil Ömrü (h)                 99 non-null     category
#  3   Pil Gücü (mAh)               39 non-null     float64
#  4   Pil Gücü (Wh)                86 non-null     category
#  5   Boşta İken Güç Tüketimi (W)  2 non-null      category
#  6   Şikayet Kategorisi           134 non-null    object
# dtypes: category(4), float64(1), object(2)
# memory usage: 6.8+ KB

# %% [markdown]
# "Batarya performansı" şikayet kategorisine ait 124 veri var.

# %%
batarya_performansi[['MARKA','MODEL','Pil Ömrü (h)','Pil Gücü (mAh)','Pil Gücü (Wh)','Boşta İken Güç Tüketimi (W)','Şikayet Kategorisi']].describe()
# Out:
#        Pil Gücü (mAh)
# count       39.000000
# mean      4239.025641
# std       1554.067710
# min       2800.000000
# 25%       3200.000000
# 50%       3220.000000
# 75%       4870.000000
# max      10000.000000

# %% [markdown]
# > *   Batarya performansı şikayetinin markalara göre kıyaslaması

# %%
batarya_performansi["MARKA"].value_counts()
# Out:
# LENOVO      55
# ASUS        42
# ACER        15
# APPLE        6
# HP           5
# HOMETECH     5
# DELL         4
# CASPER       2
# Name: MARKA, dtype: int64

# %% [markdown]
# "Batarya performansı" şikayetini en çok alan marka 55 şikayetle "LENOVO" ve onu takip eden 42 şikayetle "ASUS"

# %% [markdown]
# > *   Batarya performansı şikayetinin modele göre kıyaslaması

# %%
batarya_performansi["MODEL"].value_counts()
# Out:
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD                22
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD      10
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                   7
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD       7
# Acer Aspire A315-41G-R5J4 15.6" AMD Ryzen 3-2200 2.5 GHz / 4 GB / 1000 GB HDD                 5
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD           5
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                      4
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD                        4
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                       4
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 128 GB SSD       4
# Apple MacBook Air MQD32TU/A 13.3" Intel Core i5-5350U 1.8 GHz / 8 GB / 128 GB SSD             4
# Lenovo 81AX00ERTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 12 GB / 1 TB HDD                   3
# Lenovo IdeaPad L340-17IRH 17.3"  Intel Core i7-9750H 2.6 GHz / 16 GB / 1 TB + 256 GB SSD      3
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 256 GB SSD           3
# Asus X540UB-GO072 15.6" Intel Core i5-7200U 2.2 GHz / 4 GB / 1 TB                             3
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB     2
# Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB                         2
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD             2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                     2
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD           2
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 12 GB / 1 TB                           2
# Acer Swift 3 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 256 GB SSD                            2
# Asus Vivobook X540NA-GO067 15.6" Intel Celeron N3350 1.10 GHz / 4 GB / 512 GB HDD             2
# Acer Nitro 5 15.6" Intel Core i7-7700HQ 2.8GHz / 16GB / 1TB HDD + 128GB SSD                   2
# Acer Predator Helios 300 17.3" Intel Core i7-9750H 2.6GHz / 16GB RAM / 512GB SSD              2
# Acer Aspire A315-42G-R5W2 15.6" AMD Ryzen 5-3500U 2.1GHz / 4 GB / 256 GB SSD                  1
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                        1
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           1
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                         1
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                        1
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                             1
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                   1
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                         1
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                        1
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                           1
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                           1
# Apple MacBook Air Retina (2018) 13.3" Intel Core i5 1.6GHz / 8GB RAM / 128GB SSD              1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                             1
# Acer Aspire One AO1-132-C4RS 11.6" Intel Celeron N3060 1.6 GHz / 2 GB / 32 GB eMMC            1
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                        1
# Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB                    1
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                     1
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 256GB SSD                       1
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                     1
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           1
# Hometech HT BOOK 14 14.1"  Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                     1
# Asus FX553VD-DM160 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD          1
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                      1
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC                       1
# Asus X507MA-BR001T 15.6" Intel Celeron-N4000 2.5 GHz / 4 GB / 512 GB                          1
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                          1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Batarya performansı" şikayetini en çok alan model 22 şikayetle "Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD" ve onu takip eden 10 şikayetle "Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD"

# %% [markdown]
# >* Batarya performansı şikayetinin pil ömrüne göre kıyaslaması

# %%
batarya_performansi["Pil Ömrü (h)"].value_counts()
# Out:
# 6.0     43
# 4.0     18
# 12.0     9
# 5.0      7
# 4.5      7
# 10.0     4
# 9.0      3
# 1.0      2
# 3.0      2
# 8.5      2
# 8.0      2
# 14.0     0
# 5.5      0
# 6.5      0
# 7.5      0
# 11.0     0
# 7.0      0
# Name: Pil Ömrü (h), dtype: int64

# %% [markdown]
# "Batarya performansı" şikayeti görülen cihazlar en çok 6 saatlik pil ömrüne sahip cihazlar , ardından 4 saatlik pil ömrüne sahip cihazlar geliyor.

# %% [markdown]
# >* Batarya performansı şikayetinin pil gücüne (mAh) göre kıyaslaması

# %%
batarya_performansi["Pil Gücü (mAh)"].value_counts()
# Out:
# 3200.0     14
# 4870.0      5
# 7000.0      4
# 3220.0      4
# 4840.0      2
# 5001.0      2
# 4400.0      2
# 3720.0      2
# 2800.0      2
# 3770.0      1
# 10000.0     1
# Name: Pil Gücü (mAh), dtype: int64

# %% [markdown]
# "Batarya performansı" şikayetine sahip cihazların 14'ü 3200 mAh'lık pil gücüne sahip , onu takip eden 4870 mAh pil gücüne sahip 5 cihaz var.

# %% [markdown]
# >* Batarya performansı şikayetinin pil gücüne (Wh) göre kıyaslaması

# %%
batarya_performansi["Pil Gücü (Wh)"].value_counts()
# Out:
# 30.0    52
# 33.0     7
# 70.0     4
# 48.0     4
# 32.0     4
# 45.0     3
# 38.0     3
# 31.0     3
# 42.0     2
# 41.0     2
# 40.0     2
# 58.0     0
# 44.0     0
# 36.0     0
# Name: Pil Gücü (Wh), dtype: int64

# %% [markdown]
# "Batarya performansı" şikayetine sahip cihazların 52'si 30 Wh'luk pil gücüne sahip , onu takip eden 33 Wh pil gücüne sahip 7 cihaz var.

# %% [markdown]
# >* Batarya performansı şikayetine sahip modellerin sayısal özelliklerinin histogram grafikleri

# %%
batarya_performansi[['Pil Ömrü (h)','Pil Gücü (mAh)','Pil Gücü (Wh)','Boşta İken Güç Tüketimi (W)']].hist(bins=15, xlabelsize = 8, ylabelsize = 8)
plt.tight_layout(rect=(0, 0, 2, 2))

# %% [markdown]
# >* "Batarya performansı" şikayetine sahip modellerin sayısal özelliklerinin scatter-plot grafikleri

# %%
ozellikler = ['Pil Ömrü (h)','Pil Gücü (mAh)', 'Pil Gücü (Wh)','Boşta İken Güç Tüketimi (W)']
pp = sns.pairplot(data[ozellikler], height=1.8, aspect=1.8,plot_kws=dict(edgecolor="k", linewidth=0.5),diag_kind="kde", diag_kws=dict(shade=True))

# %% [markdown]
# >* "Batarya performansı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = batarya_performansi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# Bu grafikler sonucunda elde ettiğimiz bilgiler şu şekildedir :
#
# "Batarya performansı" şikayeti gözlenen cihazlarda ,
#
# * Pil Ömrü ile Pil Gücü (Wh) doğru orantılı,Pil Gücü (mAh) ters orantılı

# %% [markdown]
# # **5.3 ) Cihaz Ağırlığı**

# %%
cihaz_agirligi = data[data['Şikayet Kategorisi'].str.contains('Cihaz Ağırlığı')]

# %%
cihaz_agirligi[['MARKA','MODEL','Cihaz Ağırlığı (kg)','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 79 to 536
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MARKA                6 non-null      category
#  1   MODEL                6 non-null      object
#  2   Cihaz Ağırlığı (kg)  6 non-null      float64
#  3   Şikayet Kategorisi   6 non-null      object
# dtypes: category(1), float64(1), object(2)
# memory usage: 582.0+ bytes

# %% [markdown]
# "Cihaz Ağırlığı" şikayet kategorisine ait 6 veri var.

# %%
cihaz_agirligi[['MARKA','MODEL','Cihaz Ağırlığı (kg)','Şikayet Kategorisi']].describe()
# Out:
#        Cihaz Ağırlığı (kg)
# count             6.000000
# mean              2.453333
# std               0.134561
# min               2.200000
# 25%               2.432500
# 50%               2.530000
# 75%               2.530000
# max               2.530000

# %% [markdown]
# > *   Cihaz ağırlığı şikayetinin markalara göre kıyaslaması

# %%
cihaz_agirligi["MARKA"].value_counts()
# Out:
# ASUS        4
# ACER        2
# LENOVO      0
# HP          0
# HOMETECH    0
# DELL        0
# CASPER      0
# APPLE       0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Cihaz ağırlığı" şikayetini alan markalar "ASUS" ve "ACER"

# %% [markdown]
# > *   Cihaz ağırlığı şikayetinin modele göre kıyaslaması

# %%
cihaz_agirligi["MODEL"].value_counts()
# Out:
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 128 GB SSD    3
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                        1
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                   1
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD    1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Cihaz ağırlığı" şikayetini en çok alan model "Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 128 GB SSD"

# %% [markdown]
# >* Cihaz ağırlığı şikayetinin cihaz ağırlığı (kg)'na göre kıyaslaması

# %%
cihaz_agirligi["Cihaz Ağırlığı (kg)"].value_counts()
# Out:
# 2.53    4
# 2.20    1
# 2.40    1
# Name: Cihaz Ağırlığı (kg), dtype: int64

# %% [markdown]
# "Cihaz ağırlığı" şikayeti en çok "2.53" cihaz ağırlığına sahip cihazlarda gözleniyor.

# %% [markdown]
# >* "Cihaz ağırlığı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = cihaz_agirligi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# Bu grafikler sonucunda elde ettiğimiz bilgiler şu şekildedir :
#
# "Batarya performansı" şikayeti gözlenen cihazlarda ,
#
# * Pil Ömrü ile Pil Gücü (Wh) doğru orantılı,Pil Gücü (mAh) ters orantılı

# %% [markdown]
# # **5.4 ) Depolama Alanı Yetersiz**

# %%
depolama_alani_yetersiz = data[data['Şikayet Kategorisi'].str.contains('Depolama alanı yetersiz')]

# %%
depolama_alani_yetersiz[['MARKA','MODEL','Dahili Hafıza (GB)','HDD Depolama Kapasitesi (GB)']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 3 to 1743
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MARKA                         64 non-null     category
#  1   MODEL                         64 non-null     object
#  2   Dahili Hafıza (GB)            64 non-null     category
#  3   HDD Depolama Kapasitesi (GB)  12 non-null     category
# dtypes: category(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# "Depolama alanı yetersiz" şikayet kategorisine ait 64 veri var.

# %%
depolama_alani_yetersiz[['MARKA','MODEL','Dahili Hafıza (GB)','HDD Depolama Kapasitesi (GB)']].describe()
# Out:
#            MARKA  ... HDD Depolama Kapasitesi (GB)
# count         64  ...                         12.0
# unique         7  ...                          3.0
# top     HOMETECH  ...                       1000.0
# freq          14  ...                          8.0
#
# [4 rows x 4 columns]

# %% [markdown]
# > *   Depolama alanı yetersiz şikayetinin markalara göre kıyaslaması

# %%
depolama_alani_yetersiz["MARKA"].value_counts()
# Out:
# HOMETECH    14
# APPLE       14
# ACER        14
# ASUS        10
# HP           7
# LENOVO       4
# DELL         1
# CASPER       0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Depolama alanı yetersiz" şikayetini en çok alan markalar 14 şikayetle "ACER" "APPLE" ve "HOMETECH" ve onu takip eden 10 şikayetle "ASUS"

# %% [markdown]
# > *   Depolama alanı yetersiz şikayetinin modele göre kıyaslaması

# %%
depolama_alani_yetersiz["MODEL"].value_counts()
# Out:
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                     12
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC                      8
# Acer Aspire One AO1-132-C4RS 11.6" Intel Celeron N3060 1.6 GHz / 2 GB / 32 GB eMMC           7
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                          5
# Apple MacBook Air MQD32TU/A 13.3" Intel Core i5-5350U 1.8 GHz / 8 GB / 128 GB SSD            3
# Apple MacBook Pro (2015) 13" Intel Core i5 2.7Ghz / 8GB / 128GB                              3
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 128GB SSD                      3
# Acer Swift 3 14" Intel Core i3-8415U 2.1 GHz / 4 GB / 128 GB SSD                             2
# Hometech HT BOOK 14 14.1"  Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                    2
# Apple MacBook Air Retina (2018) 13.3" Intel Core i5 1.6GHz / 8GB RAM / 128GB SSD             2
# Acer Aspire A315-21-96PZ 15.6" AMD A9-9420 2.9 GHz / 4 GB / 500 GB HDD                       2
# Apple MacBook Pro Touchbar 13.3" Intel Core i5-8250U 1.44 GHz / 8 GB / 128 GB SSD            2
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD          2
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                         1
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                        1
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                     1
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 256GB SSD                      1
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                       1
# Lenovo IdeaPad L340-17IRH 17.3"  Intel Core i7-9750H 2.6 GHz / 16 GB / 1 TB + 256 GB SSD     1
# Acer Travelmate EX2519-C8AN 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD            1
# Acer Swift 3 14" Intel Core i5-10210U 2.3 GHz / 8 GB / 256 GB SSD                            1
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                    1
# Acer Nitro 5 15.6" Intel Core i7-7700HQ 2.8GHz / 16GB / 1TB HDD + 128GB SSD                  1
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                    1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Depolama alanı yetersiz" şikayetini en çok alan model 12 şikayetle "Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC " ve onu takip eden 8 şikayetle "Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC" ve 7 şikayetle "Acer Aspire One AO1-132-C4RS 11.6" Intel Celeron N3060 1.6 GHz / 2 GB / 32 GB eMMC"

# %% [markdown]
# >* Depolama alanı yetersiz şikayetinin dahili hafıza'ya göre kıyaslaması

# %%
depolama_alani_yetersiz["Dahili Hafıza (GB)"].value_counts()
# Out:
# 32      21
# 128     20
# 64       8
# 1000     4
# 1128     3
# 256      3
# 512      2
# 500      2
# 1256     1
# Name: Dahili Hafıza (GB), dtype: int64

# %% [markdown]
# "Depolama alanı yetersiz" şikayeti görülen cihazların 21 tanesi "32" ve 20 tanesi "128" gb dahili hafızaya sahipler.

# %% [markdown]
# >* Depolama alanı yetersiz şikayetinin HDD depolama kapasitesi'ne göre kıyaslaması

# %%
depolama_alani_yetersiz["HDD Depolama Kapasitesi (GB)"].value_counts()
# Out:
# 1000.0    8
# 512.0     2
# 500.0     2
# 256.0     0
# Name: HDD Depolama Kapasitesi (GB), dtype: int64

# %% [markdown]
# Burada az veri bulunduğundan karşılaştırılmaya uygun değildir."HDD Depolama Kapasitesi (GB)" alanında bu kadar az veri olmasının sebebi "Depolama alanı yetersiz" şikayetimi alan cihazlarda çoğunlukla SSD depolama bulunmasıdır.

# %% [markdown]
# >* "Depolama alanı yetersiz" şikayetine sahip modellerin sayısal özelliklerinin scatter-plot grafikleri

# %%
ozellikler = ['Dahili Hafıza (GB)','HDD Depolama Kapasitesi (GB)']
pp = sns.pairplot(data[ozellikler], height=1.8, aspect=1.8,plot_kws=dict(edgecolor="k", linewidth=0.5),diag_kind="kde", diag_kws=dict(shade=True))

# %% [markdown]
# >* "Depolama alanı yetersiz" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = depolama_alani_yetersiz.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# Bu grafikler sonucunda elde ettiğimiz bilgiler şu şekildedir :
#
# "Depolama alanı yetersiz" şikayeti gözlenen cihazlarda ,
#
# * HDD Depolama Kapasitesi (GB) ile Dahili Hafıza (GB)'nın doğru orantılı olduğu gözlenmiştir.

# %% [markdown]
# # **5.5 ) Ekran Kartı Performansı**

# %%
ekran_karti_performansi = data[data['Şikayet Kategorisi'].str.contains('Ekran kartı performansı')]

# %%
ekran_karti_performansi[['MARKA','MODEL','Ekran Kartı Modeli','Ekran Kartı Tipi','Ekran Kartı Bellek Tipi','Ekran Kartı Hafızası (GB)','Dahili Grafik Kartı Mevcuttur','GPU Bellek Hızı (MHz)','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 3 to 1759
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MARKA                          76 non-null     category
#  1   MODEL                          76 non-null     object
#  2   Ekran Kartı Modeli             76 non-null     object
#  3   Ekran Kartı Tipi               76 non-null     object
#  4   Ekran Kartı Bellek Tipi        74 non-null     category
#  5   Ekran Kartı Hafızası (GB)      68 non-null     category
#  6   Dahili Grafik Kartı Mevcuttur  76 non-null     object
#  7   GPU Bellek Hızı (MHz)          73 non-null     float64
#  8   Şikayet Kategorisi             76 non-null     object
# dtypes: category(3), float64(1), object(5)
# memory usage: 5.1+ KB

# %% [markdown]
# "Ekran kartı performansı" şikayet kategorisine ait 76 veri var.

# %%
ekran_karti_performansi[['MARKA','MODEL','Ekran Kartı Modeli','Ekran Kartı Tipi','Ekran Kartı Bellek Tipi','Ekran Kartı Hafızası (GB)','Dahili Grafik Kartı Mevcuttur','GPU Bellek Hızı (MHz)','Şikayet Kategorisi']].describe()
# Out:
#        GPU Bellek Hızı (MHz)
# count              73.000000
# mean              943.534247
# std               250.468066
# min               300.000000
# 25%               780.000000
# 50%               967.000000
# 75%              1024.000000
# max              1485.000000

# %% [markdown]
# > *   Ekran kartı performansı şikayetinin markalara göre kıyaslaması

# %%
ekran_karti_performansi["MARKA"].value_counts()
# Out:
# ASUS        27
# LENOVO      20
# DELL        13
# ACER         8
# HP           4
# CASPER       4
# HOMETECH     0
# APPLE        0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Ekran kartı performansı" şikayetini en çok alan marka 27 şikayetle "ASUS" , onu takip eden 20 şikayetle "LENOVO" ve 13 şikayetle "DELL"

# %% [markdown]
# > *   Ekran kartı performansı şikayetinin modele göre kıyaslaması

# %%
ekran_karti_performansi["MODEL"].value_counts()
# Out:
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                  7
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                    6
# Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB                   6
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD          5
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD      5
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                       5
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                         4
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD          4
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                            3
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                    3
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                        2
# Lenovo 81AX00ERTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 12 GB / 1 TB HDD                  2
# Lenovo IdeaPad L340-17IRH 17.3"  Intel Core i7-9750H 2.6 GHz / 16 GB / 1 TB + 256 GB SSD     2
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                  2
# Acer Aspire A315-42G-R5W2 15.6" AMD Ryzen 5-3500U 2.1GHz / 4 GB / 256 GB SSD                 2
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                  2
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                          2
# Acer Aspire A315-21-96PZ 15.6" AMD A9-9420 2.9 GHz / 4 GB / 500 GB HDD                       2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                   1
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                       1
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB    1
# Asus VivoBook X556UQ 15.6" Intel Core i7-7500U 2.7GHz / 16GB / 1TB                           1
# Acer Swift 3 14" Intel Core i3-8415U 2.1 GHz / 4 GB / 128 GB SSD                             1
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                   1
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                        1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 256 GB SSD          1
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 128 GB SSD      1
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                       1
# Acer Swift 3 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 256 GB SSD                           1
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD      1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Ekran kartı performansı" şikayetini en çok alan model 7 şikayetle "Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB " ve onu takip eden 6 şikayetle "Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB  " ve "Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB "

# %% [markdown]
# >* Ekran kartı performansı şikayetinin Ekran kartı modeline göre kıyaslaması

# %%
ekran_karti_performansi["Ekran Kartı Modeli"].value_counts()
# Out:
# AMD Radeon 530              18
# Nvidia GeForce GT930MX      10
# AMD Radeon R5 M420           6
# AMD Radeon 520               6
# AMD Radeon R7 M445           6
# NVIDIA GeForce GTX 1050      4
# Intel HD Graphics 5500       4
# Nvidia GeForce GTX950M       3
# Nvidia GeForce GTX960M       2
# AMD Radeon 500               2
# Nvidia GeForce GTX1650       2
# AMD Radeon 540X              2
# AMD Radeon R2 Graphics       2
# NVIDIA GeForce 940MX         2
# Nvidia GeForce 930MX         1
# \tNvidia GeForce GT940MX     1
# NVIDIA GeForce MX100         1
# Intel UHD Graphics 620       1
# Nvidia GeForce GT940MX       1
# Nvidia GeForce MX150         1
# AMD Radeon R5 M430           1
# Name: Ekran Kartı Modeli, dtype: int64

# %% [markdown]
# "Ekran kartı performansı" şikayetini en çok alan ekran kartı modeli 18 şikayetle "AMD Radeon 530" ve 10 şikayetle "Nvidia GeForce GT930MX"

# %% [markdown]
# >* Ekran kartı performansı şikayetinin ekran kartı tipine göre kıyaslaması

# %%
ekran_karti_performansi["Ekran Kartı Tipi"].value_counts()
# Out:
# Harici Ekran Kartı                  62
# Dahili Ekran Kartı                   9
# Yüksek Seviye Harici Ekran Kartı     5
# Name: Ekran Kartı Tipi, dtype: int64

# %% [markdown]
# Ekran kartı performansını şikayetini en çok alan ekran kartı tipi "Harici Ekran Kartı"

# %% [markdown]
# >* Ekran kartı performansı şikayetinin ekran kartı bellek tipine göre kıyaslaması

# %%
ekran_karti_performansi["Ekran Kartı Bellek Tipi"].value_counts()
# Out:
# GDDR5      40
# DDR3       23
# Onboard     7
# GDDR3       4
# GDDR4       0
# Name: Ekran Kartı Bellek Tipi, dtype: int64

# %% [markdown]
# "Ekran kartı performansı" şikayetini en çok alan ekran kartı bellek tipi "GDDR5"

# %% [markdown]
# >  * Ekran kartı performansı şikayetinin ekran kartı hafızasına göre kıyaslaması

# %%
ekran_karti_performansi["Ekran Kartı Hafızası (GB)"].value_counts()
# Out:
# 2.0    58
# 4.0     9
# 1.0     1
# 6.0     0
# 3.0     0
# Name: Ekran Kartı Hafızası (GB), dtype: int64

# %% [markdown]
# "Ekran kartı performansı" şikayetini en çok alan ekran kartı hafızası "2.00 GB"

# %% [markdown]
# >  * Ekran kartı performansı şikayetinin dahili grafik kartı mevcuttura göre kıyaslaması

# %%
ekran_karti_performansi["Dahili Grafik Kartı Mevcuttur"].value_counts()
# Out:
# Evet    76
# Name: Dahili Grafik Kartı Mevcuttur, dtype: int64

# %% [markdown]
# >  * Ekran kartı performansı şikayetinin GPU bellek hızına göre kıyaslaması

# %%
ekran_karti_performansi["GPU Bellek Hızı (MHz)"].value_counts()
# Out:
# 1024.0    15
# 780.0     13
# 952.0     11
# 1030.0     6
# 300.0      4
# 1354.0     4
# 914.0      3
# 967.0      3
# 1485.0     2
# 1200.0     2
# 400.0      2
# 1096.0     2
# 800.0      2
# 1072.0     1
# 1468.0     1
# 1000.0     1
# 965.0      1
# Name: GPU Bellek Hızı (MHz), dtype: int64

# %% [markdown]
# "Ekran kartı performansı" şikayetini en çok alan GPU bellek hızı 15 şikayetle "1024.0",13 şikayetle "780.0" ve 11 şikayetle "950.0"

# %% [markdown]
# >* Ekran kartı performansı şikayetine sahip modellerin sayısal özelliklerinin histogram grafikleri

# %%
ekran_karti_performansi[['Ekran Kartı Hafızası (GB)','GPU Bellek Hızı (MHz)']].hist(bins=5, xlabelsize = 8, ylabelsize = 8)
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %% [markdown]
# >* "Ekran kartı performansı" şikayetine sahip modellerin sayısal özelliklerinin scatter-plot grafikleri

# %%
ozellikler = ['Ekran Kartı Hafızası (GB)','GPU Bellek Hızı (MHz)']
pp = sns.pairplot(data[ozellikler], height=2, aspect=2,plot_kws=dict(edgecolor="k", linewidth=0.5),diag_kind="kde", diag_kws=dict(shade=True))

# %% [markdown]
# >* "Ekran kartı performansı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = ekran_karti_performansi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.6 ) Donma Sorunu**

# %%
donma_sorunu = data[data['Şikayet Kategorisi'].str.contains('Donma sorunu')]

# %%
donma_sorunu[['MARKA','MODEL','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 12 to 1548
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MARKA               115 non-null    category
#  1   MODEL               115 non-null    object
#  2   Şikayet Kategorisi  115 non-null    object
# dtypes: category(1), object(2)
# memory usage: 3.2+ KB

# %% [markdown]
# "Donma sorunu" şikayet kategorisine ait 115 veri var.

# %%
donma_sorunu[['MARKA','MODEL','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count    115  ...                115
# unique     8  ...                 54
# top     ASUS  ...       Donma sorunu
# freq      53  ...                 36
#
# [4 rows x 3 columns]

# %% [markdown]
# > *   Donma sorunu şikayetinin markalara göre kıyaslaması

# %%
donma_sorunu["MARKA"].value_counts()
# Out:
# ASUS        53
# HP          22
# HOMETECH    15
# ACER         9
# LENOVO       7
# APPLE        4
# CASPER       3
# DELL         2
# Name: MARKA, dtype: int64

# %% [markdown]
# "Donma sorunu" şikayetini en çok alan marka 53 şikayetle "ASUS"

# %% [markdown]
# > *   Donma sorunu şikayetinin modele göre kıyaslaması

# %%
donma_sorunu["MODEL"].value_counts()
# Out:
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                    15
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                 9
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                   8
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                           5
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                   5
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                        5
# Asus Vivobook X540NA-GO067 15.6" Intel Celeron N3350 1.10 GHz / 4 GB / 512 GB HDD           4
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                 4
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                         4
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                   4
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD         3
# Asus X507MA-BR001T 15.6" Intel Celeron-N4000 2.5 GHz / 4 GB / 512 GB                        3
# Acer Nitro 5 15.6" Intel Core i7-7700HQ 2.8GHz / 16GB / 1TB HDD + 128GB SSD                 3
# Asus VivoBook TP501UQ-CJ019TC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 512 GB HDD         3
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD     3
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                       3
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                         2
# Acer Nitro 5 15.6" Intel Core i5-8300H 2.3 GHz / 8GB / 1TB HDD + 128 GB SSD                 2
# Asus X540UB-GO072 15.6" Intel Core i5-7200U 2.2 GHz / 4 GB / 1 TB                           2
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                 2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                  2
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                       2
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                      2
# Apple MacBook Air MQD32TU/A 13.3" Intel Core i5-5350U 1.8 GHz / 8 GB / 128 GB SSD           2
# Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB                       1
# Apple MacBook Pro MR9U2TU/A 13" Intel Core i5 2.3 GHz  / 8 GB / 256 GB                      1
# Acer Aspire A315-41G-R5J4 15.6" AMD Ryzen 3-2200 2.5 GHz / 4 GB / 1000 GB HDD               1
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                         1
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 256GB SSD                     1
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                           1
# Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB                  1
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                  1
# Acer Nitro 5 15.6" Intel Core i5-9300H 2.4GHz / 8GB RAM / 512GB SSD                         1
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                      1
# Lenovo Ideapad 320 80XL006PTX 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1 TB HDD          1
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                         1
# Asus VivoBook X556UQ 15.6" Intel Core i7-7500U 2.7GHz / 16GB / 1TB                          1
# ASUS X550VX-DM248TC 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                1
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD           1
# Acer Aspire One AO1-132-C4RS 11.6" Intel Celeron N3060 1.6 GHz / 2 GB / 32 GB eMMC          1
# Asus X541SA-XX038D 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                    1
# Lenovo 81AX00ERTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 12 GB / 1 TB HDD                 1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Donma sorunu" şikayetini en çok alan model 15 şikayetle "Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC" onu takip eden 9 şikayetle "ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD" ve de 8 şikayetle "Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB"

# %%
corr = donma_sorunu.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.6 ) Ekran Performansı**

# %%
ekran_performansi = data[data['Şikayet Kategorisi'].str.contains('Ekran performansı')]

# %%
ekran_performansi[['MARKA','MODEL','Çözünürlük (px)','Ekran Boyutu (inç)','Yansıma Önleyici Kaplaması Vardır','Dokunmatik Ekran Vardır','Ekran Panel Tipi','Desteklenen Ekranlar','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 1755
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   MARKA                              147 non-null    category
#  1   MODEL                              147 non-null    object
#  2   Çözünürlük (px)                    147 non-null    category
#  3   Ekran Boyutu (inç)                 147 non-null    category
#  4   Yansıma Önleyici Kaplaması Vardır  102 non-null    object
#  5   Dokunmatik Ekran Vardır            146 non-null    object
#  6   Ekran Panel Tipi                   146 non-null    category
#  7   Desteklenen Ekranlar               93 non-null     float64
#  8   Şikayet Kategorisi                 147 non-null    object
# dtypes: category(4), float64(1), object(4)
# memory usage: 8.3+ KB

# %% [markdown]
# "Ekran performansı" şikayet kategorisine ait 135 veri var.

# %%
ekran_performansi[['MARKA','MODEL','Çözünürlük (px)','Ekran Boyutu (inç)','Yansıma Önleyici Kaplaması Vardır','Dokunmatik Ekran Vardır','Ekran Panel Tipi','Desteklenen Ekranlar','Şikayet Kategorisi']].describe()
# Out:
#        Desteklenen Ekranlar
# count             93.000000
# mean               2.935484
# std                0.437544
# min                0.000000
# 25%                3.000000
# 50%                3.000000
# 75%                3.000000
# max                3.000000

# %% [markdown]
# > *   Ekran performansı şikayetinin markalara göre kıyaslaması

# %%
ekran_performansi["MARKA"].value_counts()
# Out:
# ASUS        45
# LENOVO      37
# ACER        22
# DELL        17
# HP          15
# APPLE       11
# HOMETECH     0
# CASPER       0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Ekran performansı" şikayetini en çok alan marka 40 şikayetle "ASUS" , onu takip eden 36 şikayetle "LENOVO"

# %% [markdown]
# > *   Ekran performansı şikayetinin model'e göre kıyaslaması

# %%
ekran_performansi["MODEL"].value_counts()
# Out:
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD                18
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD           8
# Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB                    7
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                    6
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                           6
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                        5
# Apple MacBook Air MQD32TU/A 13.3" Intel Core i5-5350U 1.8 GHz / 8 GB / 128 GB SSD             4
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                        4
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                           4
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD       4
# Asus VivoBook TP501UQ-CJ019TC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 512 GB HDD           3
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB     3
# Acer Nitro 5 15.6" Intel Core i7-7700HQ 2.8GHz / 16GB / 1TB HDD + 128GB SSD                   3
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC                       3
# Lenovo IdeaPad L340-17IRH 17.3"  Intel Core i7-9750H 2.6 GHz / 16 GB / 1 TB + 256 GB SSD      3
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                             3
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD             3
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           3
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                    3
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                   2
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                     2
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                      2
# Apple MacBook Air Retina (2018) 13.3" Intel Core i5 1.6GHz / 8GB RAM / 128GB SSD              2
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 128 GB SSD       2
# Acer Nitro 5 15.6" Intel Core i5-9300H 2.4GHz / 8GB RAM / 256GB SSD                           2
# Acer Swift 3 14" Intel Core i5-10210U 2.3 GHz / 8 GB / 256 GB SSD                             2
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                     2
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           2
# Acer Aspire 3 15.6" Intel Celeron N4000 1.1GHz / 4GB RAM / 128GB SSD                          2
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 256 GB SSD           2
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                   2
# Acer E5-575G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                           2
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD                        2
# Acer Nitro 5 15.6" Intel Core i5-8300H 2.3 GHz / 8GB / 1TB HDD + 128 GB SSD                   1
# Apple MacBook Pro (2015) 13" Intel Core i5 2.7Ghz / 8GB / 128GB                               1
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 8 GB / 1 TB                            1
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD       1
# Acer Travelmate EX2519-C8AN 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD             1
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                        1
# Acer Aspire A315-21-96PZ 15.6" AMD A9-9420 2.9 GHz / 4 GB / 500 GB HDD                        1
# Acer Swift 3 14" Intel Core i3-8415U 2.1 GHz / 4 GB / 128 GB SSD                              1
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                     1
# Acer Swift 3 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 256 GB SSD                            1
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                     1
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 128GB SSD                       1
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                          1
# Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD                   1
# Acer Nitro 5 15.6" Intel Core i5-9300H 2.4GHz / 8GB RAM / 512GB SSD                           1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                             1
# Acer Aspire One AO1-132-C4RS 11.6" Intel Celeron N3060 1.6 GHz / 2 GB / 32 GB eMMC            1
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                        1
# Apple MacBook Air (2015) 13" Intel Core i5 1.6GHz / 4GB / 128GB                               1
# Asus K555UQ-DM028DC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 1000 GB HDD                    1
# Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB                         1
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                   1
# Apple MacBook Pro MR9U2TU/A 13" Intel Core i5 2.3 GHz  / 8 GB / 256 GB                        1
# Apple MacBook Pro Touchbar 13.3" Intel Core i5-8250U 1.44 GHz / 8 GB / 128 GB SSD             1
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 12 GB / 1 TB                           1
# HP 250 G6 (3QM27EA) 15.6" Intel Core i3-7020U 2.3 GHz / 4 GB / 512 GB                         1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Ekran performansı" şikayetini en çok alan model 18 şikayetle "Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD" ve onu takip eden 8 şikayetle "Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD"

# %% [markdown]
# >* Ekran performansı şikayetinin çözünürlüğe göre kıyaslaması

# %%
ekran_performansi["Çözünürlük (px)"].value_counts()
# Out:
# 1920 x 1080    66
# 1366 x 768     64
# 3840 x 2160     6
# 2560 x 1600     6
# 1440 x 900      5
# Name: Çözünürlük (px), dtype: int64

# %% [markdown]
# "Ekran performansı" şikayetini en çok alan modeller "1920 x 1080" ve "1366 x 768" ekran çözünürlüğüne sahiptir.

# %% [markdown]
# >* Ekran performansı şikayetinin ekran boyutuna göre kıyaslaması

# %%
ekran_performansi["Ekran Boyutu (inç)"].value_counts()
# Out:
# 15.6    126
# 13.3     11
# 14.0      6
# 17.3      3
# 11.6      1
# 14.1      0
# Name: Ekran Boyutu (inç), dtype: int64

# %% [markdown]
# Ekran performansı şikayetini en çok alan ekran boyutu "15.6"

# %% [markdown]
# >* Ekran performansı şikayetinin yansıma önleyici kaplaması vardır'a göre kıyaslaması

# %%
ekran_performansi["Yansıma Önleyici Kaplaması Vardır"].value_counts()
# Out:
# Evet     76
# Hayır    26
# Name: Yansıma Önleyici Kaplaması Vardır, dtype: int64

# %% [markdown]
# "Ekran performansı" şikayetini alan cihazların 71 tanesi yansıma önleyici kaplamaya sahip olup 25 tanesi sahip değildir.

# %% [markdown]
# >  * Ekran performansı şikayetinin dokunmatik ekran vardır'a göre kıyaslaması

# %%
ekran_performansi["Dokunmatik Ekran Vardır"].value_counts()
# Out:
# Hayır    143
# Evet       3
# Name: Dokunmatik Ekran Vardır, dtype: int64

# %% [markdown]
# "Ekran performansı" şikayetini alan cihazların çoğunluğu dokunmatik ekrana sahip değildir.

# %% [markdown]
# >  * Ekran performansı şikayetinin ekran panel tipi'ne göre kıyaslaması

# %%
ekran_performansi["Ekran Panel Tipi"].value_counts()
# Out:
# TN     106
# IPS     25
# SVA     15
# Name: Ekran Panel Tipi, dtype: int64

# %% [markdown]
# Ekran performansı şikayetini alan cihazların çoğunluğu TN ekran paneline sahiptir.

# %% [markdown]
# >  * Ekran performansı şikayetinin desteklenen ekranlar'a göre kıyaslaması

# %%
ekran_performansi["Desteklenen Ekranlar"].value_counts()
# Out:
# 3.0    91
# 0.0     2
# Name: Desteklenen Ekranlar, dtype: int64

# %% [markdown]
# "Ekran performansı" şikayetini alan cihazların çoğunluğu "3.0" desteklenen ekran'a sahip

# %% [markdown]
# >* Ekran performansı şikayetine sahip modellerin sayısal özelliklerinin histogram grafikleri

# %%
ekran_performansi[['Ekran Boyutu (inç)','Desteklenen Ekranlar']].hist(bins=5, xlabelsize = 8, ylabelsize = 8)
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %% [markdown]
# >* "Ekran performansı" şikayetine sahip modellerin sayısal özelliklerinin scatter-plot grafikleri

# %%
ozellikler = ['Ekran Boyutu (inç)','Desteklenen Ekranlar']
pp = sns.pairplot(data[ozellikler], height=2, aspect=2,plot_kws=dict(edgecolor="k", linewidth=0.5),diag_kind="kde", diag_kws=dict(shade=True))

# %% [markdown]
# >* "Ekran performansı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = ekran_performansi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.7 ) HDD Performansı**

# %%
hdd_performansi = data[data['Şikayet Kategorisi'].str.contains('HDD performansı')]

# %%
hdd_performansi[['MARKA','MODEL','HDD Depolama Kapasitesi (GB)','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 12 to 1697
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MARKA                         67 non-null     category
#  1   MODEL                         67 non-null     object
#  2   HDD Depolama Kapasitesi (GB)  65 non-null     category
#  3   Şikayet Kategorisi            67 non-null     object
# dtypes: category(2), object(2)
# memory usage: 2.3+ KB

# %% [markdown]
# "HDD performansı" şikayet kategorisine ait 67 veri var.

# %%
hdd_performansi[['MARKA','MODEL','HDD Depolama Kapasitesi (GB)','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count     67  ...                 67
# unique     7  ...                 39
# top     ASUS  ...    HDD performansı
# freq      26  ...                 16
#
# [4 rows x 4 columns]

# %% [markdown]
# > *   HDD performansı şikayetinin markalara göre kıyaslaması

# %%
hdd_performansi["MARKA"].value_counts()
# Out:
# ASUS        26
# ACER        15
# HP           9
# LENOVO       8
# DELL         6
# CASPER       2
# APPLE        1
# HOMETECH     0
# Name: MARKA, dtype: int64

# %% [markdown]
# "HDD performansı" şikayetini en çok alan markalar 26 şikayetle "ASUS" ve 15 şikayetle "ACER"

# %% [markdown]
# > *   HDD performansı şikayetinin modele göre kıyaslaması

# %%
hdd_performansi["MODEL"].value_counts()
# Out:
# Acer E5-575G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                        5
# Acer Aspire A315-41G-R5J4 15.6" AMD Ryzen 3-2200 2.5 GHz / 4 GB / 1000 GB HDD              4
# HP 250 G6 (3QM27EA) 15.6" Intel Core i3-7020U 2.3 GHz / 4 GB / 512 GB                      3
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                3
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                 3
# Lenovo Ideapad 320 80XL006QTX 15.6"  Intel Core i5-7200U 2.5 GHz / 4 GB / 1 TB HDD         3
# Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD                3
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                          2
# Acer V3-574G-56F3 15.6" Intel Core i5-5200U 2.2 GHz / 8 GB / 1000 GB HDD                   2
# Asus VivoBook TP501UQ-CJ019TC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 512 GB HDD        2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                  2
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD        2
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                        2
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                       2
# Asus VivoBook X556UQ 15.6" Intel Core i7-7500U 2.7GHz / 16GB / 1TB                         2
# Acer Aspire A515-51G-388J 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 500 GB HDD            2
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD          2
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                     2
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                     2
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                  1
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                   1
# Dell Inspiron 5567-G20W45C 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 512 GB               1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD        1
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                      1
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD    1
# Apple MacBook Air MQD32TU/A 13.3" Intel Core i5-5350U 1.8 GHz / 8 GB / 128 GB SSD          1
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                        1
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                1
# Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB                 1
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                      1
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC                    1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                          1
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                  1
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD    1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD                     1
# Asus Vivobook X540NA-GO067 15.6" Intel Celeron N3350 1.10 GHz / 4 GB / 512 GB HDD          1
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                 1
# Lenovo 81AX00ERTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 12 GB / 1 TB HDD                1
# Name: MODEL, dtype: int64

# %% [markdown]
# "HDD performansı" şikayetini en çok alan model 5 şikayetle "Acer E5-575G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD " ve 4 şikayetle "Acer Aspire A315-41G-R5J4 15.6" AMD Ryzen 3-2200 2.5 GHz / 4 GB / 1000 GB HDD"

# %% [markdown]
# >* HDD performansı şikayetinin cihaz ağırlığı (kg)'na göre kıyaslaması

# %%
hdd_performansi["HDD Depolama Kapasitesi (GB)"].value_counts()
# Out:
# 1000.0    53
# 512.0     10
# 500.0      2
# 256.0      0
# Name: HDD Depolama Kapasitesi (GB), dtype: int64

# %% [markdown]
# "HDD performansı" şikayetine en çok "1000" HDD depolama kapasitesindeki cihazlar sahiptir

# %% [markdown]
# >* "HDD performansı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = hdd_performansi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.8 ) Isınma Sorunu**

# %%
isinma_sorunu = data[data['Şikayet Kategorisi'].str.contains('Isınma sorunu')]

# %%
isinma_sorunu[['MARKA','MODEL','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 26 to 1734
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MARKA               124 non-null    category
#  1   MODEL               124 non-null    object
#  2   Şikayet Kategorisi  124 non-null    object
# dtypes: category(1), object(2)
# memory usage: 3.4+ KB

# %% [markdown]
# "Isınma sorunu" şikayet kategorisine ait 124 veri var.

# %%
isinma_sorunu[['MARKA','MODEL','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count    124  ...                124
# unique     8  ...                 58
# top     ASUS  ...      Isınma sorunu
# freq      42  ...                 44
#
# [4 rows x 3 columns]

# %% [markdown]
# > *  Isınma sorunu şikayetinin markalara göre kıyaslaması

# %%
isinma_sorunu["MARKA"].value_counts()
# Out:
# ASUS        42
# ACER        29
# LENOVO      14
# HP          11
# HOMETECH    11
# APPLE       10
# CASPER       4
# DELL         3
# Name: MARKA, dtype: int64

# %% [markdown]
# "Isınma sorunu" şikayetini en çok alan marka 42 şikayetle "ASUS" ve 29 şikayetle "ACER"

# %% [markdown]
# > *   Isınma sorunu şikayetinin modele göre kıyaslaması

# %%
isinma_sorunu["MODEL"].value_counts()
# Out:
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                      11
# Acer Nitro 5 15.6" Intel Core i5-8300H 2.3 GHz / 8GB / 1TB HDD + 128 GB SSD                  11
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                     7
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD       6
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 128GB SSD                       5
# Acer Nitro 5 15.6" Intel Core i7-7700HQ 2.8GHz / 16GB / 1TB HDD + 128GB SSD                   5
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                   4
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           4
# Asus FX553VD-DM160 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD          4
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD           4
# Apple MacBook Pro Touchbar 13.3" Intel Core i5-8250U 1.44 GHz / 8 GB / 128 GB SSD             3
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                      3
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                    3
# Acer Swift 3 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 256 GB SSD                            3
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 256 GB SSD           3
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                   3
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                        3
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                     3
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                      3
# HP 250 G6 (3QM27EA) 15.6" Intel Core i3-7020U 2.3 GHz / 4 GB / 512 GB                         2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                    2
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD       2
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                     2
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD                 2
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD             2
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 256GB SSD                       2
# Acer F5-573G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                           2
# Acer Aspire A515-51G-388J 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 500 GB HDD               2
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           2
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 128 GB SSD       2
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                        1
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                           1
# Acer Swift 3 14" Intel Core i5-10210U 2.3 GHz / 8 GB / 256 GB SSD                             1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD           1
# Acer Aspire A315-42G-R5W2 15.6" AMD Ryzen 5-3500U 2.1GHz / 4 GB / 256 GB SSD                  1
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB     1
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                         1
# Asus Vivobook X540NA-GO067 15.6" Intel Celeron N3350 1.10 GHz / 4 GB / 512 GB HDD             1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                             1
# Acer Nitro 5 15.6" Intel Core i5-9300H 2.4GHz / 8GB RAM / 512GB SSD                           1
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                     1
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                         1
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                   1
# Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD                   1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Isınma sorunu" şikayetini en çok alan model 11 şikayetle "Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC" ve "Acer Nitro 5 15.6" Intel Core i5-8300H 2.3 GHz / 8GB / 1TB HDD + 128 GB SSD"

# %%
corr = isinma_sorunu.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.9 ) İşlemci Performansı**

# %%
islemci_performansi = data[data['Şikayet Kategorisi'].str.contains('İşlemci performansı')]

# %%
islemci_performansi[['MARKA','MODEL','İşlemci Modeli','İşlemci Nesli','İşlemci Hızı (GHz)','İşlemci Çekirdek Sayısı','CPU İş Parçacığı','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 3 to 1706
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MARKA                    71 non-null     category
#  1   MODEL                    71 non-null     object
#  2   İşlemci Modeli           71 non-null     object
#  3   İşlemci Nesli            47 non-null     object
#  4   İşlemci Hızı (GHz)       71 non-null     category
#  5   İşlemci Çekirdek Sayısı  71 non-null     category
#  6   CPU İş Parçacığı         70 non-null     category
#  7   Şikayet Kategorisi       71 non-null     object
# dtypes: category(4), object(4)
# memory usage: 4.5+ KB

# %% [markdown]
# "İşlemci performansı" şikayet kategorisine ait 71 veri var.

# %%
islemci_performansi[['MARKA','MODEL','İşlemci Modeli','İşlemci Nesli','İşlemci Hızı (GHz)','İşlemci Çekirdek Sayısı','CPU İş Parçacığı','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ...   Şikayet Kategorisi
# count     71  ...                   71
# unique     7  ...                   27
# top     ASUS  ...  İşlemci performansı
# freq      28  ...                   34
#
# [4 rows x 8 columns]

# %% [markdown]
# > *   İşlemci performansı şikayetinin markalara göre kıyaslaması

# %%
islemci_performansi["MARKA"].value_counts()
# Out:
# ASUS        28
# HP          16
# LENOVO      12
# ACER         7
# HOMETECH     3
# APPLE        3
# DELL         2
# CASPER       0
# Name: MARKA, dtype: int64

# %% [markdown]
# "İşlemci performansı" şikayetini en çok alan marka 28 şikayetle "ASUS" , onu takip eden 16 şikayetle "HP" ve 12 şikayetle "DELL"

# %% [markdown]
# > *   İşlemci performansı şikayetinin modele göre kıyaslaması

# %%
islemci_performansi["MODEL"].value_counts()
# Out:
# Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB                      6
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                      6
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                5
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                        5
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                  4
# Acer Aspire A315-21-96PZ 15.6" AMD A9-9420 2.9 GHz / 4 GB / 500 GB HDD                     4
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                  4
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                        4
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                      3
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                       3
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                    3
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                2
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                     2
# Asus Vivobook X540NA-GO067 15.6" Intel Celeron N3350 1.10 GHz / 4 GB / 512 GB HDD          2
# HP 250 G6 (3QM27EA) 15.6" Intel Core i3-7020U 2.3 GHz / 4 GB / 512 GB                      1
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD    1
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                  1
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                 1
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                        1
# Acer Aspire ES1-572-50L3 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 500 GB HDD             1
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                          1
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                   1
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                1
# Apple MacBook Pro (2015) 13" Intel Core i5 2.7Ghz / 8GB / 128GB                            1
# Apple MacBook Air MQD32TU/A 13.3" Intel Core i5-5350U 1.8 GHz / 8 GB / 128 GB SSD          1
# Acer Aspire A515-51G-388J 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 500 GB HDD            1
# Apple MacBook Pro (2018) 13" Intel Core i5 2.3GHz / 8GB RAM / 128GB SSD                    1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                          1
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                  1
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                 1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD        1
# Lenovo 81AX00ERTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 12 GB / 1 TB HDD                1
# Name: MODEL, dtype: int64

# %% [markdown]
# "İşlemci performansı" şikayetini en çok alan model 6 şikayetle "Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB " ve "Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB " , 5 şikayetle "HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD" ve "Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD"

# %% [markdown]
# >* İşlemci performansı şikayetinin işlemci modeline göre kıyaslaması

# %%
islemci_performansi["İşlemci Modeli"].value_counts()
# Out:
# AMD A9-9420             12
# Intel Core i5-8250U      8
# Intel Core i3-5005U      7
# Intel Celeron-N4000      6
# Intel Celeron-N3060      6
# AMD E1-7010              6
# AMD A12-9720P            5
# Intel Core i5-7200U      3
# Intel Core i7-6700HQ     3
# Intel Atom Z3735F        3
# Intel Celeron-N3350      2
# Intel Core i3-6006U      2
# Intel Core i7-8550U      2
# Intel Core i5-7360U      1
# Intel Core i5-5350U      1
# Intel Core i5-5257U      1
# Intel Core i3-7020U      1
# AMD A6-9220              1
# Intel Core i3 6006U      1
# Name: İşlemci Modeli, dtype: int64

# %% [markdown]
# "İşlemci performansı" şikayetini en çok alan işlemci modeli 12 şikayetle "AMD A9-9420 " ve 8 şikayetle "Intel Core i5-8250U"

# %% [markdown]
# >* İşlemci performansı şikayetinin işlemci nesli'ne göre kıyaslaması

# %%
islemci_performansi["İşlemci Nesli"].value_counts()
# Out:
# Intel Celeron    14
# 8.Nesil          10
# 5.Nesil           9
# 6.Nesil           6
# 7.Nesil           5
# Intel Atom        3
# Name: İşlemci Nesli, dtype: int64

# %% [markdown]
# İşlemci performansı şikayetini en çok alan işlemci nesli 14 şikayetle "Intel Celeron" , 10 şikayetle "8.Nesil" ve 9 şikayetle "5.Nesil"

# %% [markdown]
# >* İşlemci performansı şikayetinin İşlemci hızı'na göre kıyaslaması

# %%
islemci_performansi["İşlemci Hızı (GHz)"].value_counts()
# Out:
# 1.6     14
# 2.9     12
# 2.0     10
# 1.1      8
# 2.7      6
# 1.5      6
# 2.5      4
# 1.33     3
# 2.6      3
# 1.8      3
# 2.3      2
# 1.44     0
# 3.8      0
# 2.1      0
# 2.4      0
# 2.8      0
# 2.2      0
# Name: İşlemci Hızı (GHz), dtype: int64

# %% [markdown]
# "İşlemci performansı" şikayetini en çok alan işlemci hızı 14 şikayetle "1.6" GHz 12 şikayetle "2.9" GHz ve 10 şikayetle "2.00" GHz

# %% [markdown]
# >  * Ekran kartı performansı şikayetinin ekran kartı hafızasına göre kıyaslaması

# %%
islemci_performansi["İşlemci Çekirdek Sayısı"].value_counts()
# Out:
# 2.0    50
# 4.0    21
# 6.0     0
# Name: İşlemci Çekirdek Sayısı, dtype: int64

# %% [markdown]
# "İşlemci performansı" şikayetini en çok alan işlemci çekirdek sayısı "2.00"

# %% [markdown]
# >  * İşlemci performansı şikayetinin CPU iş parçacığı'na göre kıyaslaması

# %%
islemci_performansi["CPU İş Parçacığı"].value_counts()
# Out:
# 2.0     32
# 4.0     25
# 8.0     13
# 12.0     0
# Name: CPU İş Parçacığı, dtype: int64

# %% [markdown]
# "İşlemci performansı" şikayetini en çok alan CPU iş parçacığı 32 şikayetle "2.00" ve 25 şikayetle "4.00"

# %% [markdown]
# >* "İşlemci performansı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = islemci_performansi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# Bu grafikler sonucunda elde ettiğimiz bilgiler şu şekildedir :
#
# "İşlemci performansı" şikayeti gözlenen cihazlarda ,
#
# * İşlemci hızı , işlemci çekirdek hızı ve CPU iş parçacığı'ndan bağımsızdır.
# * İşlemci çekirdek sayısı , CPU iş parçacığı ile doğru orantılıdır.

# %% [markdown]
# # **5.10 ) Kasma Sorunu**

# %%
kasma_sorunu = data[data['Şikayet Kategorisi'].str.contains('Kasma sorunu')]

# %%
kasma_sorunu[['MARKA','MODEL','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122 entries, 304 to 1736
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MARKA               122 non-null    category
#  1   MODEL               122 non-null    object
#  2   Şikayet Kategorisi  122 non-null    object
# dtypes: category(1), object(2)
# memory usage: 3.4+ KB

# %% [markdown]
# "Kasma sorunu" şikayet kategorisine ait 122 veri var.

# %%
kasma_sorunu[['MARKA','MODEL','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count    122  ...                122
# unique     6  ...                 51
# top     ASUS  ...       Kasma sorunu
# freq      55  ...                 42
#
# [4 rows x 3 columns]

# %% [markdown]
# > *   Kasma sorunu şikayetinin markalara göre kıyaslaması

# %%
kasma_sorunu["MARKA"].value_counts()
# Out:
# ASUS        55
# HP          37
# HOMETECH    12
# LENOVO       9
# DELL         7
# CASPER       2
# APPLE        0
# ACER         0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Kasma sorunu" şikayetini en çok alan marka 55 şikayetle "ASUS" ve 37 şikayetle "HP"

# %% [markdown]
# > *   Kasma sorunu şikayetinin modele göre kıyaslaması

# %%
kasma_sorunu["MODEL"].value_counts()
# Out:
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                          12
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                      11
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                    10
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           6
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                          6
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                             5
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                     4
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                         4
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                         4
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB     4
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                    4
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                        4
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                   3
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                        3
# HP 250 G6 (3QM27EA) 15.6" Intel Core i3-7020U 2.3 GHz / 4 GB / 512 GB                         3
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD             3
# Asus X507MA-BR060T 15.6" Intel Celeron-N4000 1.10 GHz / 4 GB / 500 GB                         3
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                     2
# Dell Inspiron 5567-G20W45C 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 512 GB                  2
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 12 GB / 1 TB                           2
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 8 GB / 1 TB                            2
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD           2
# Asus VivoBook X556UQ 15.6" Intel Core i7-7500U 2.7GHz / 16GB / 1TB                            2
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                     2
# Asus Vivobook X540NA-GO067 15.6" Intel Celeron N3350 1.10 GHz / 4 GB / 512 GB HDD             2
# Lenovo Ideapad 320 80XL006PTX 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1 TB HDD            2
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                      2
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                           1
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                        1
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD       1
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                   1
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD                 1
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                             1
# Asus X507MA-BR001T 15.6" Intel Celeron-N4000 2.5 GHz / 4 GB / 512 GB                          1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD           1
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                        1
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                   1
# Hometech HT BOOK 14 14.1"  Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                     1
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC                       1
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 256 GB SSD           1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Kasma sorunu" şikayetini en çok alan model 12 şikayetle "HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD " , 11 şikayetle "Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC" ve 10 şikayetle "Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB"

# %%
corr = kasma_sorunu.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.11 ) Malzeme Kalitesi**

# %%
malzeme_kalitesi = data[data['Şikayet Kategorisi'].str.contains('Malzeme kalitesi')]

# %%
malzeme_kalitesi[['MARKA','MODEL','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 16 to 1709
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MARKA               139 non-null    category
#  1   MODEL               139 non-null    object
#  2   Şikayet Kategorisi  139 non-null    object
# dtypes: category(1), object(2)
# memory usage: 3.8+ KB

# %% [markdown]
# "Malzeme kalitesi" şikayet kategorisine ait 139 veri var.

# %%
malzeme_kalitesi[['MARKA','MODEL','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count    139  ...                139
# unique     7  ...                 62
# top     ASUS  ...   Malzeme kalitesi
# freq      74  ...                 50
#
# [4 rows x 3 columns]

# %% [markdown]
# > *   Malzeme kalitesi şikayetinin markalara göre kıyaslaması

# %%
malzeme_kalitesi["MARKA"].value_counts()
# Out:
# ASUS        74
# HP          22
# LENOVO      18
# DELL        12
# CASPER       5
# HOMETECH     4
# ACER         4
# APPLE        0
# Name: MARKA, dtype: int64

# %% [markdown]
# "Malzeme kalitesi" şikayetini en çok alan marka "ASUS"

# %% [markdown]
# > *   Malzeme kalitesi şikayetinin modele göre kıyaslaması

# %%
malzeme_kalitesi["MODEL"].value_counts()
# Out:
# Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD                  18
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD                13
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                          12
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                         8
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 8 GB / 1000 GB HDD                    7
# ASUS X550VX-DM324D 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1000 GB HDD                   6
# HP 15-BW016NT 15.6" AMD A6-9220 2.5 GHz / 4 GB / 1 TB HDD                                     5
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD           5
# Dell Inspiron 5567-G20W81C 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1 TB                    4
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD             4
# Asus X540UB-GO072 15.6" Intel Core i5-7200U 2.2 GHz / 4 GB / 1 TB                             4
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                       3
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1000 GB HDD                    3
# Dell Inspiron 3567 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 1 TB HDD                        3
# Dell Inspiron 3580 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 1 TB HDD                        3
# Asus K556UQ-XX935T 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                     3
# Asus FX553VD-DM160 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD          3
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                   3
# Asus VivoBook X556UQ 15.6" Intel Core i7-7500U 2.7GHz / 16GB / 1TB                            2
# Asus VivoBook X542UR-GQ029T 15.6" Intel Core Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB     2
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                     2
# Lenovo V330-15IKB 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB  HDD + 128 GB SSD           2
# Asus K555UB-XO266T 15.6" Intel Core i5-6200U 2.3 GHz / 8 GB / 1 TB                            2
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                      2
# Lenovo Ideapad 320 80XL006PTX 15.6" Intel Core i5-7200U 2.5 GHz / 12 GB / 1 TB HDD            2
# Acer E5-575G 15.6" Intel Core i5-7200U 2.5 GHz / 8 GB / 1000 GB HDD                           2
# Asus E402NA-GA046T 14" Intel Celeron-N3350 1.10 GHz / 4 GB / 64 GB eMMC                       2
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                      1
# Asus D509DA-BR129T 15.6" AMD Ryzen 3-3200U 2.6 GHz / 4 GB / 256 GB SSD                        1
# Lenovo 81AX00ESTX V330 15.6" Intel Core i7 8550U 1.8 GHz / 8 GB / 1 TB HDD + 128 GB SSD       1
# Acer Aspire A315-41G-R5J4 15.6" AMD Ryzen 3-2200 2.5 GHz / 4 GB / 1000 GB HDD                 1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                             1
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           1
# Dell Inspiron 5567-G20W45C 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 512 GB                  1
# Hometech HT BOOK 14 14.1"  Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                     1
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                           1
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                         1
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                        1
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                          1
# HP 250 G6 (3QM27EA) 15.6" Intel Core i3-7020U 2.3 GHz / 4 GB / 512 GB                         1
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                             1
# Name: MODEL, dtype: int64

# %% [markdown]
# "Malzeme kalitesi" şikayetini en çok alan model 18 şikayetle "Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD" , 13 şikayetle "Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD" ve 12 şikayetle "HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD"

# %%
corr = malzeme_kalitesi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# # **5.12 ) RAM Performansı**

# %%
ram_performansi = data[data['Şikayet Kategorisi'].str.contains('RAM performansı')]

# %%
ram_performansi[['MARKA','MODEL','Ram (GB)','Ram Hızı (MHz)','Şikayet Kategorisi']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 13 to 1664
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MARKA               103 non-null    category
#  1   MODEL               103 non-null    object
#  2   Ram (GB)            103 non-null    category
#  3   Ram Hızı (MHz)      93 non-null     category
#  4   Şikayet Kategorisi  103 non-null    object
# dtypes: category(3), object(2)
# memory usage: 3.7+ KB

# %% [markdown]
# "RAM performansı" şikayet kategorisine ait 103 veri var.

# %%
ram_performansi[['MARKA','MODEL','Ram (GB)','Ram Hızı (MHz)','Şikayet Kategorisi']].describe()
# Out:
#        MARKA  ... Şikayet Kategorisi
# count    103  ...                103
# unique     8  ...                 41
# top     ASUS  ...    RAM performansı
# freq      42  ...                 46
#
# [4 rows x 5 columns]

# %% [markdown]
# > *   RAM performansı şikayetinin markalara göre kıyaslaması

# %%
ram_performansi["MARKA"].value_counts()
# Out:
# ASUS        42
# ACER        31
# HP          11
# LENOVO       8
# DELL         4
# HOMETECH     3
# CASPER       3
# APPLE        1
# Name: MARKA, dtype: int64

# %% [markdown]
# "Ram performansı" şikayetini en çok alan markalar 42 şikayetle "ASUS" ve 31 şikayetle "ACER"

# %% [markdown]
# > *   RAM performansı şikayetinin modele göre kıyaslaması

# %%
ram_performansi["MODEL"].value_counts()
# Out:
# Acer Swift 3 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 256 GB SSD                         15
# Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB                          12
# Asus X540UB-GQ359 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                       8
# Lenovo Ideapad 320 80XV004ETX 15.6" AMD A9-9420 2.9 GHz / 4 GB / 1 TB HDD                   6
# Asus K555UB-XO099D 15.6"  Intel Core i5-6200U 2.30 GHz / 4 GB / 1000 GB HDD                 5
# Acer Aspire A315-41G-R5J4 15.6" AMD Ryzen 3-2200 2.5 GHz / 4 GB / 1000 GB HDD               4
# Asus VivoBook X542UR-GQ276 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 1000 GB HDD           4
# HP 15-BS154NT 15.6" Intel Core i3-5005U 2.0 GHz / 4 GB / 128 GB SSD                         3
# Hometech Alfa 110A 11.6" Intel Atom-Z3735F 1.33 GHz / 2 GB / 32 GB eMMC                     3
# Casper Nirvana C900.7700-8TG0X 15.6" Intel Core i7-7700HQ 2.8 GHz / 8 GB / 1 TB HDD         3
# Acer E5-576G-50GL 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1000 GB HDD                    3
# Asus Vivobook X540YA-XO185D 15.6" AMD E1-7010 1.5 GHz / 2 GB / 512 GB                       3
# Asus VivoBook 15 X505BP-BR019 15.6" AMD A9 9420  2.9 GHz / 4 GB / 1000 GB                   3
# HP 15-RA012NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                         3
# Dell Inspiron 5567-G20W45C 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 512 GB                2
# HP 15-RA013NT 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD                         2
# Acer Aspire A315-42G-R5W2 15.6" AMD Ryzen 5-3500U 2.1GHz / 4 GB / 256 GB SSD                2
# Asus VivoBook TP501UQ-CJ019TC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 512 GB HDD         2
# Acer Aspire ES1-572-50L3 15.6" Intel Core i5-7200U 2.5 GHz / 4 GB / 500 GB HDD              2
# Dell Inspiron 3576 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                      2
# HP 15-BS153NT 15.6" Intel Core i3 5005U 2.0 GHz / 4 GB / 1000 GB HDD                        2
# Acer Aspire A515-51G-388J 15.6" Intel Core i3-6006U 2.0 GHz / 4 GB / 500 GB HDD             2
# Asus Vivobook X542UR-GQ438T 15.6" Intel Core i5-8250U 1.6 GHz / 8 GB / 1 TB                 1
# Lenovo IdeaPad S145-15API 15.6" AMD Ryzen 7 3700U 2.3 GHz / 8 GB / 512 GB SSD               1
# Apple MacBook Pro Touchbar 13.3" Intel Core i5-8250U 1.44 GHz / 8 GB / 128 GB SSD           1
# Asus VivoBook Pro N552VW 15.6" Intel Core i7-6700HQ 2.6 GHz / 16 GB / 1 TB + 256 GB SSD     1
# Asus X507MA-BR001T 15.6" Intel Celeron-N4000 2.5 GHz / 4 GB / 512 GB                        1
# Asus X509FB-BR102T 15.6" Intel Core i5-8265U 1.6 GHz / 8 GB / 256 GB SSD                    1
# Acer Aspire One AO1-132-C4RS 11.6" Intel Celeron N3060 1.6 GHz / 2 GB / 32 GB eMMC          1
# Acer Aspire VN7-791G 17.3" Intel Core i7-4710HQ 2.5GHz / 16GB / 1TB\n                       1
# Lenovo Ideapad 320 80XS008NTX 15.6" AMD A12-9720P 2.7 GHz / 8 GB / 1 TB HDD                 1
# HP 15-BS102NT 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB HDD                           1
# Asus K555UQ-DM028DC 15.6" Intel Core i5-6200U 2.3 GHz / 4 GB / 1000 GB HDD                  1
# Acer Travelmate EX2519-C8AN 15.6" Intel Celeron-N3060 1.6 GHz / 4 GB / 512 GB HDD           1
# Name: MODEL, dtype: int64

# %% [markdown]
# "RAM performansı" şikayetini en çok alan model 15 şikayetle "Acer Swift 3 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 256 GB SSD" ve 12 şikayetle "Asus X542UR-GQ434 15.6" Intel Core i5-8250U 1.6 GHz / 4 GB / 1 TB"

# %% [markdown]
# >* RAM performansı şikayetinin ram'e göre kıyaslaması

# %%
ram_performansi["Ram (GB)"].value_counts()
# Out:
# 4     83
# 8     11
# 2      7
# 16     2
# 12     0
# Name: Ram (GB), dtype: int64

# %% [markdown]
# "RAM performansı" şikayetini en çok "4" GB ram'e sahip cihazlar almıştır.

# %% [markdown]
# >* RAM performansı şikayetinin ram hızı'na göre kıyaslaması

# %%
ram_performansi["Ram Hızı (MHz)"].value_counts()
# Out:
# 2133.0    42
# 1600.0    26
# 2400.0    24
# 1333.0     1
# 3733.0     0
# 2666.0     0
# 1866.0     0
# 1066.0     0
# Name: Ram Hızı (MHz), dtype: int64

# %% [markdown]
# "RAM performansı" şikayetini en çok "2133" MHz ram hızına sahip cihazlar almıştır.

# %% [markdown]
# >* "RAM performansı" şikayetine sahip modellerin tüm özelliklerinin birbiriyle ilişkisini gösteren grafik

# %%
corr = ram_performansi.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');

# %% [markdown]
# Bu grafikler sonucunda elde ettiğimiz bilgiler şu şekildedir :
#
# "RAM performansı" şikayeti gözlenen cihazlarda ,
#
# * Ram ile ram hızı bağımsızdır.
